# %%
import ipums_etl

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 1. ETL Data Pipeline
# Here we extract the data from various CSVs, transform it using DuckDB and load the result into a postgres database. We do this in several steps:
# - 1.1 Extract ipums demographic data and the census place project geographic data into a duckdb database.
# - 1.2 Transform the data by: merging the demographic and geographic data into a single table called census. Aggregating the data to the census place industry level (census_place_industry_count table).
# - 1.3 Loading the aggregated data into a postgres database, together with auxiliary data (industry codes, census places)
# - 1.4 Building the relations between tables in the database

# %%
ipums_etl.extract_data_to_duckdb()
# Out:
# 2024-05-15 09:48:12,688 INFO sqlalchemy.engine.Engine select current_schema()
# 2024-05-15 09:48:12,689 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-05-15 09:48:12,690 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 09:48:12,694 INFO sqlalchemy.engine.Engine -- Drop tables if they exist for idempotency
# DROP TABLE IF EXISTS "dem_1850";
# DROP TABLE IF EXISTS "geo_1850";
#
# -- Create demographic data table
# CREATE TABLE "dem_1850"
#     (year INTEGER,
#      occ1950 INTEGER,
#      ind1950 INTEGER,
#      histid VARCHAR(36),
#      hik VARCHAR(21));
#
# COPY "dem_1850" FROM '/Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ipums/census/usa_1850.csv';
#
# CREATE INDEX "index_dem_1850_histid" ON "dem_1850" (histid);
#
# WITH duplicates AS (
#     SELECT histid, ROW_NUMBER() OVER(PARTITION BY histid) AS rownum
#     FROM "dem_1850"
#     )
# DELETE FROM "dem_1850" USING duplicates
# WHERE "dem_1850".histid = duplicates.histid AND duplicates.rownum > 1;
#
# -- Create geographic data table
# CREATE TABLE "geo_1850"
#     (potential_match VARCHAR(50),
#      match_type VARCHAR(50),
#      lat FLOAT,
#      lon FLOAT,
#      state_fips_geomatch VARCHAR(2),
#      county_fips_geomatch VARCHAR(5),
#      cluster_k5 INTEGER,
#      cpp_placeid INTEGER,
#      histid VARCHAR(36)
# );
# COPY "geo_1850" FROM '/Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ipums/geo/histid_place_crosswalk_1850.csv';
#
#
# -- Transform histid to uppercase
# CREATE TABLE "geo_1850_new" (census_place_id INTEGER, histid VARCHAR(36));
#
# INSERT INTO "geo_1850_new"
# SELECT cpp_placeid, UPPER(histid) FROM "geo_1850";
#
# DROP TABLE "geo_1850";
# ALTER TABLE "geo_1850_new" RENAME TO "geo_1850";
#
# -- Create index
# CREATE INDEX "index_geo_1850_histid" ON "geo_1850" (histid);
#
# -- Remove duplicates
# WITH duplicates AS (
#     SELECT histid, ROW_NUMBER() OVER(PARTITION BY histid) AS rownum
#     FROM "geo_1850"
#     )
# DELETE FROM "geo_1850" USING duplicates
# WHERE "geo_1850".histid = duplicates.histid AND duplicates.rownum > 1;
# 2024-05-15 09:48:12,694 INFO sqlalchemy.engine.Engine [dialect duckdb+duckdb_engine does not support caching 0.00037s] ()
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 2024-05-15 09:48:29,105 INFO sqlalchemy.engine.Engine COMMIT
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 2024-05-15 09:49:00,380 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 09:49:00,382 INFO sqlalchemy.engine.Engine -- Drop tables if they exist for idempotency
# DROP TABLE IF EXISTS "dem_1860";
# DROP TABLE IF EXISTS "geo_1860";
#
# -- Create demographic data table
# CREATE TABLE "dem_1860"
#     (year INTEGER,
#      occ1950 INTEGER,
#      ind1950 INTEGER,
#      histid VARCHAR(36),
#      hik VARCHAR(21));
#
# COPY "dem_1860" FROM '/Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ipums/census/usa_1860.csv';
#
# CREATE INDEX "index_dem_1860_histid" ON "dem_1860" (histid);
#
# WITH duplicates AS (
#     SELECT histid, ROW_NUMBER() OVER(PARTITION BY histid) AS rownum
#     FROM "dem_1860"
#     )
# DELETE FROM "dem_1860" USING duplicates
# WHERE "dem_1860".histid = duplicates.histid AND duplicates.rownum > 1;
#
# -- Create geographic data table
# CREATE TABLE "geo_1860"
#     (potential_match VARCHAR(50),
#      match_type VARCHAR(50),
#      lat FLOAT,
#      lon FLOAT,
#      state_fips_geomatch VARCHAR(2),
#      county_fips_geomatch VARCHAR(5),
#      cluster_k5 INTEGER,
#      cpp_placeid INTEGER,
#      histid VARCHAR(36)
# );
# COPY "geo_1860" FROM '/Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ipums/geo/histid_place_crosswalk_1860.csv';
#
#
# -- Transform histid to uppercase
# CREATE TABLE "geo_1860_new" (census_place_id INTEGER, histid VARCHAR(36));
#
# INSERT INTO "geo_1860_new"
# SELECT cpp_placeid, UPPER(histid) FROM "geo_1860";
#
# DROP TABLE "geo_1860";
# ALTER TABLE "geo_1860_new" RENAME TO "geo_1860";
#
# -- Create index
# CREATE INDEX "index_geo_1860_histid" ON "geo_1860" (histid);
#
# -- Remove duplicates
# WITH duplicates AS (
#     SELECT histid, ROW_NUMBER() OVER(PARTITION BY histid) AS rownum
#     FROM "geo_1860"
#     )
# DELETE FROM "geo_1860" USING duplicates
# WHERE "geo_1860".histid = duplicates.histid AND duplicates.rownum > 1;
# 2024-05-15 09:49:00,382 INFO sqlalchemy.engine.Engine [dialect duckdb+duckdb_engine does not support caching 0.00027s] ()
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 2024-05-15 09:49:21,211 INFO sqlalchemy.engine.Engine COMMIT
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
ipums_etl.transform_data()
# Out:
# 2024-05-15 10:02:04,830 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 10:02:04,832 INFO sqlalchemy.engine.Engine -- Drop tables if they exist for idempotency
# DROP TABLE IF EXISTS "census_1850";
# DROP TABLE IF EXISTS "census_place_industry_count_1850";
#
# -- Create census table
# CREATE TABLE "census_1850"
#     (histid VARCHAR(36),
#      hik VARCHAR(21),
#      ind1950 INTEGER,
#      occ1950 INTEGER,
#      census_place_id INTEGER);
#
# -- Merge the data from the demographic and geographic tables
# INSERT INTO "census_1850"
# SELECT "dem_1850".histid, NULLIF(hik, '                     '), ind1950, occ1950, CASE WHEN census_place_id > 69491 THEN NULL ELSE census_place_id END AS census_place_id
# FROM "dem_1850" LEFT JOIN "geo_1850"
# ON "dem_1850".histid = "geo_1850".histid;
#
# -- Create census place industry count table
# CREATE TABLE "census_place_industry_count_1850" AS
# SELECT census_place_id, ind1950, COUNT(*) AS worker_count
# FROM "census_1850"
# WHERE census_place_id IS NOT NULL
# GROUP BY census_place_id, ind1950;
# 2024-05-15 10:02:04,833 INFO sqlalchemy.engine.Engine [dialect duckdb+duckdb_engine does not support caching 0.00038s] ()
# 2024-05-15 10:02:06,525 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 10:02:06,774 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 10:02:06,775 INFO sqlalchemy.engine.Engine -- Drop tables if they exist for idempotency
# DROP TABLE IF EXISTS "census_1860";
# DROP TABLE IF EXISTS "census_place_industry_count_1860";
#
# -- Create census table
# CREATE TABLE "census_1860"
#     (histid VARCHAR(36),
#      hik VARCHAR(21),
#      ind1950 INTEGER,
#      occ1950 INTEGER,
#      census_place_id INTEGER);
#
# -- Merge the data from the demographic and geographic tables
# INSERT INTO "census_1860"
# SELECT "dem_1860".histid, NULLIF(hik, '                     '), ind1950, occ1950, CASE WHEN census_place_id > 69491 THEN NULL ELSE census_place_id END AS census_place_id
# FROM "dem_1860" LEFT JOIN "geo_1860"
# ON "dem_1860".histid = "geo_1860".histid;
#
# -- Create census place industry count table
# CREATE TABLE "census_place_industry_count_1860" AS
# SELECT census_place_id, ind1950, COUNT(*) AS worker_count
# FROM "census_1860"
# WHERE census_place_id IS NOT NULL
# GROUP BY census_place_id, ind1950;
# 2024-05-15 10:02:06,776 INFO sqlalchemy.engine.Engine [dialect duckdb+duckdb_engine does not support caching 0.00021s] ()
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 2024-05-15 10:02:09,205 INFO sqlalchemy.engine.Engine COMMIT

# %%
ipums_etl.load_data_to_postgres()
# Out:
# 2024-05-15 10:05:40,526 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 10:05:40,529 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS "census_place";
# DROP TABLE IF EXISTS "industry1950_code";
#
# -- Create table for census place data
# CREATE TABLE "census_place" (
#     lat FLOAT,
#     lon FLOAT,
#     consistent_place_3 INTEGER,
#     consistent_place_name_3 VARCHAR(50),
#     consistent_place_5 INTEGER,
#     consistent_place_name_5 VARCHAR(50),
#     consistent_place_10 INTEGER,
#     consistent_place_name_10 VARCHAR(50),
#     consistent_place_50 INTEGER,
#     consistent_place_name_50 VARCHAR(50),
#     consistent_place_100 INTEGER,
#     consistent_place_name_100 VARCHAR(50),
#     consistent_place_200 INTEGER,
#     consistent_place_name_200 VARCHAR(50),
#     consistent_place_300 INTEGER,
#     consistent_place_name_300 VARCHAR(50),
#     consistent_place_500 INTEGER,
#     consistent_place_name_500 VARCHAR(50),
#     fracpop FLOAT,
#     potential_match VARCHAR(50),
#     id INTEGER
# );
#
# COPY "census_place" FROM '/data/ipums/geo/place_component_crosswalk.csv' DELIMITER ',' CSV HEADER;
#
# -- Refactor table to include geometry columns and drop needless columns
# CREATE TABLE "census_place_new"
#     (id INTEGER PRIMARY KEY,
#      potential_match VARCHAR(50),
#      geom GEOGRAPHY
#     );
#
# INSERT INTO "census_place_new"
# SELECT id, potential_match, ST_MakePoint(lon, lat)::GEOGRAPHY AS geom
# FROM "census_place";
#
# DROP TABLE "census_place";
# ALTER TABLE "census_place_new" RENAME TO "census_place";
#
# CREATE INDEX ON "census_place" USING GIST (geom);
#
# -- Create table for industry codes
# CREATE TABLE "industry1950_code" (
#     code INTEGER,
#     description VARCHAR(70),
#     refined_categories VARCHAR(70),
#     broad_categories VARCHAR(70),
#     agri_non_agri VARCHAR(70),
#     detailed VARCHAR(70),
#     no_agriculture VARCHAR(70),
#     all_group_by VARCHAR (70)
# );
#
# COPY "industry1950_code" FROM '/data/ipums/census/industry1950_codes_and_desc.csv' DELIMITER ',' CSV HEADER;
#
# ALTER TABLE "industry1950_code" ADD PRIMARY KEY (code);
# 2024-05-15 10:05:40,530 INFO sqlalchemy.engine.Engine [cached since 34.12s ago] {}
# 2024-05-15 10:05:40,925 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 10:05:40,929 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 10:05:40,930 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS census_place_industry_count_1850
# 2024-05-15 10:05:40,930 INFO sqlalchemy.engine.Engine [cached since 34.11s ago] {}
# 2024-05-15 10:05:40,931 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 10:05:40,932 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 10:05:40,933 INFO sqlalchemy.engine.Engine SELECT * FROM census_place_industry_count_1850
# 2024-05-15 10:05:40,933 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-05-15 10:05:40,941 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 10:05:40,941 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-05-15 10:05:40,942 INFO sqlalchemy.engine.Engine [cached since 34.09s ago] {'table_name': 'census_place_industry_count_1850', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-05-15 10:05:40,943 INFO sqlalchemy.engine.Engine
# CREATE TABLE census_place_industry_count_1850 (
# 	census_place_id BIGINT,
# 	ind1950 BIGINT,
# 	worker_count BIGINT
# )
#
#
# 2024-05-15 10:05:40,943 INFO sqlalchemy.engine.Engine [no key 0.00018s] {}
# 2024-05-15 10:05:40,963 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 10:05:40,964 INFO sqlalchemy.engine.Engine [generated in 0.01412s (insertmanyvalues) 1/10 (unordered)] {'worker_count__0': 147, 'census_place_id__0': 17861, 'ind1950__0': 105, 'worker_count__1': 1, 'census_place_id__1': 17861, 'ind1950__1': 488, 'worker_count__2': 5, 'census_place_id__2': 14609, 'ind1950__2': 817, 'worker_count__3': 7, 'census_place_id__3': 14609, 'ind1950__3': 246, 'worker_count__4': 183, 'census_place_id__4': 15008, 'ind1950__4': 0, 'worker_count__5': 58, 'census_place_id__5': 15454, 'ind1950__5': 105, 'worker_count__6': 202, 'census_place_id__6': 16265, 'ind1950__6': 0, 'worker_count__7': 189, 'census_place_id__7': 15581, 'ind1950__7': 105, 'worker_count__8': 1, 'census_place_id__8': 15581, 'ind1950__8': 488, 'worker_count__9': 1, 'census_place_id__9': 15581, 'ind1950__9': 499, 'worker_count__10': 5, 'census_place_id__10': 10861, 'ind1950__10': 817, 'worker_count__11': 10, 'census_place_id__11': 10861, 'ind1950__11': 246, 'worker_count__12': 3, 'census_place_id__12': 10861, 'ind1950__12': 679, 'worker_count__13': 1, 'census_place_id__13': 15100, 'ind1950__13': 817, 'worker_count__14': 1, 'census_place_id__14': 10861, 'ind1950__14': 309, 'worker_count__15': 2, 'census_place_id__15': 10861, 'ind1950__15': 526, 'worker_count__16': 1, 'census_place_id__16': 10861 ... 2900 parameters truncated ... 'census_place_id__983': 43451, 'ind1950__983': 488, 'worker_count__984': 3, 'census_place_id__984': 43451, 'ind1950__984': 499, 'worker_count__985': 5, 'census_place_id__985': 43451, 'ind1950__985': 356, 'worker_count__986': 6, 'census_place_id__986': 43451, 'ind1950__986': 416, 'worker_count__987': 2, 'census_place_id__987': 43451, 'ind1950__987': 899, 'worker_count__988': 4, 'census_place_id__988': 43683, 'ind1950__988': 896, 'worker_count__989': 292, 'census_place_id__989': 43892, 'ind1950__989': 105, 'worker_count__990': 22, 'census_place_id__990': 43892, 'ind1950__990': 488, 'worker_count__991': 2, 'census_place_id__991': 43892, 'ind1950__991': 499, 'worker_count__992': 2, 'census_place_id__992': 43892, 'ind1950__992': 906, 'worker_count__993': 1, 'census_place_id__993': 43931, 'ind1950__993': 308, 'worker_count__994': 1, 'census_place_id__994': 42495, 'ind1950__994': 489, 'worker_count__995': 18, 'census_place_id__995': 42495, 'ind1950__995': 546, 'worker_count__996': 3, 'census_place_id__996': 42495, 'ind1950__996': 308, 'worker_count__997': 1, 'census_place_id__997': 42495, 'ind1950__997': 916, 'worker_count__998': 5, 'census_place_id__998': 42186, 'ind1950__998': 308, 'worker_count__999': 2, 'census_place_id__999': 42186, 'ind1950__999': 487}
# 2024-05-15 10:05:40,972 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 10:05:40,972 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/10 (unordered)] {'worker_count__0': 12, 'census_place_id__0': 42186, 'ind1950__0': 546, 'worker_count__1': 4, 'census_place_id__1': 42186, 'ind1950__1': 489, 'worker_count__2': 1679, 'census_place_id__2': 42802, 'ind1950__2': 0, 'worker_count__3': 1, 'census_place_id__3': 42802, 'ind1950__3': 636, 'worker_count__4': 1, 'census_place_id__4': 41838, 'ind1950__4': 429, 'worker_count__5': 48, 'census_place_id__5': 41838, 'ind1950__5': 246, 'worker_count__6': 6, 'census_place_id__6': 41838, 'ind1950__6': 679, 'worker_count__7': 6, 'census_place_id__7': 41838, 'ind1950__7': 888, 'worker_count__8': 22, 'census_place_id__8': 41838, 'ind1950__8': 817, 'worker_count__9': 4, 'census_place_id__9': 41838, 'ind1950__9': 448, 'worker_count__10': 4, 'census_place_id__10': 41838, 'ind1950__10': 309, 'worker_count__11': 19, 'census_place_id__11': 41838, 'ind1950__11': 337, 'worker_count__12': 2, 'census_place_id__12': 41838, 'ind1950__12': 388, 'worker_count__13': 1, 'census_place_id__13': 41838, 'ind1950__13': 526, 'worker_count__14': 1, 'census_place_id__14': 41838, 'ind1950__14': 898, 'worker_count__15': 1042, 'census_place_id__15': 41773, 'ind1950__15': 0, 'worker_count__16': 3, 'census_place_id__16': 41773 ... 2900 parameters truncated ... 'census_place_id__983': 47901, 'ind1950__983': 868, 'worker_count__984': 6, 'census_place_id__984': 47835, 'ind1950__984': 817, 'worker_count__985': 8, 'census_place_id__985': 47835, 'ind1950__985': 246, 'worker_count__986': 223, 'census_place_id__986': 47915, 'ind1950__986': 105, 'worker_count__987': 2, 'census_place_id__987': 47915, 'ind1950__987': 499, 'worker_count__988': 2, 'census_place_id__988': 47915, 'ind1950__988': 488, 'worker_count__989': 467, 'census_place_id__989': 47988, 'ind1950__989': 0, 'worker_count__990': 1, 'census_place_id__990': 47988, 'ind1950__990': 636, 'worker_count__991': 1, 'census_place_id__991': 47988, 'ind1950__991': 307, 'worker_count__992': 1, 'census_place_id__992': 47915, 'ind1950__992': 436, 'worker_count__993': 289, 'census_place_id__993': 47980, 'ind1950__993': 0, 'worker_count__994': 2, 'census_place_id__994': 46900, 'ind1950__994': 309, 'worker_count__995': 15, 'census_place_id__995': 46900, 'ind1950__995': 817, 'worker_count__996': 14, 'census_place_id__996': 46900, 'ind1950__996': 246, 'worker_count__997': 5, 'census_place_id__997': 46900, 'ind1950__997': 526, 'worker_count__998': 3, 'census_place_id__998': 46900, 'ind1950__998': 337, 'worker_count__999': 1, 'census_place_id__999': 46900, 'ind1950__999': 679}
# 2024-05-15 10:05:40,978 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 10:05:40,979 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/10 (unordered)] {'worker_count__0': 4, 'census_place_id__0': 46900, 'ind1950__0': 888, 'worker_count__1': 45, 'census_place_id__1': 39775, 'ind1950__1': 868, 'worker_count__2': 16, 'census_place_id__2': 39775, 'ind1950__2': 326, 'worker_count__3': 52, 'census_place_id__3': 39775, 'ind1950__3': 379, 'worker_count__4': 27, 'census_place_id__4': 39775, 'ind1950__4': 409, 'worker_count__5': 2, 'census_place_id__5': 39775, 'ind1950__5': 726, 'worker_count__6': 5, 'census_place_id__6': 39775, 'ind1950__6': 619, 'worker_count__7': 1, 'census_place_id__7': 39775, 'ind1950__7': 859, 'worker_count__8': 2, 'census_place_id__8': 35696, 'ind1950__8': 318, 'worker_count__9': 2, 'census_place_id__9': 35123, 'ind1950__9': 656, 'worker_count__10': 1, 'census_place_id__10': 35123, 'ind1950__10': 879, 'worker_count__11': 1, 'census_place_id__11': 33358, 'ind1950__11': 516, 'worker_count__12': 1, 'census_place_id__12': 33514, 'ind1950__12': 409, 'worker_count__13': 3, 'census_place_id__13': 33514, 'ind1950__13': 379, 'worker_count__14': 1, 'census_place_id__14': 33514, 'ind1950__14': 868, 'worker_count__15': 4, 'census_place_id__15': 33358, 'ind1950__15': 896, 'worker_count__16': 440, 'census_place_id__16': 33077 ... 2900 parameters truncated ... 'census_place_id__983': 27961, 'ind1950__983': 669, 'worker_count__984': 12, 'census_place_id__984': 27849, 'ind1950__984': 105, 'worker_count__985': 26, 'census_place_id__985': 27849, 'ind1950__985': 488, 'worker_count__986': 1, 'census_place_id__986': 27849, 'ind1950__986': 416, 'worker_count__987': 2, 'census_place_id__987': 28203, 'ind1950__987': 896, 'worker_count__988': 290, 'census_place_id__988': 28410, 'ind1950__988': 0, 'worker_count__989': 1, 'census_place_id__989': 28410, 'ind1950__989': 636, 'worker_count__990': 3, 'census_place_id__990': 28410, 'ind1950__990': 836, 'worker_count__991': 4, 'census_place_id__991': 28199, 'ind1950__991': 439, 'worker_count__992': 6, 'census_place_id__992': 28199, 'ind1950__992': 699, 'worker_count__993': 18, 'census_place_id__993': 27449, 'ind1950__993': 105, 'worker_count__994': 16, 'census_place_id__994': 27449, 'ind1950__994': 488, 'worker_count__995': 1, 'census_place_id__995': 27449, 'ind1950__995': 906, 'worker_count__996': 3, 'census_place_id__996': 31500, 'ind1950__996': 669, 'worker_count__997': 6, 'census_place_id__997': 31500, 'ind1950__997': 879, 'worker_count__998': 14, 'census_place_id__998': 31500, 'ind1950__998': 656, 'worker_count__999': 1, 'census_place_id__999': 31500, 'ind1950__999': 437}
# 2024-05-15 10:05:40,985 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 10:05:40,985 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/10 (unordered)] {'worker_count__0': 318, 'census_place_id__0': 31393, 'ind1950__0': 105, 'worker_count__1': 8, 'census_place_id__1': 31393, 'ind1950__1': 488, 'worker_count__2': 4, 'census_place_id__2': 31411, 'ind1950__2': 656, 'worker_count__3': 1531, 'census_place_id__3': 31929, 'ind1950__3': 0, 'worker_count__4': 7, 'census_place_id__4': 31929, 'ind1950__4': 836, 'worker_count__5': 3, 'census_place_id__5': 31929, 'ind1950__5': 636, 'worker_count__6': 1, 'census_place_id__6': 31929, 'ind1950__6': 307, 'worker_count__7': 12, 'census_place_id__7': 30944, 'ind1950__7': 489, 'worker_count__8': 20, 'census_place_id__8': 30944, 'ind1950__8': 546, 'worker_count__9': 33, 'census_place_id__9': 30944, 'ind1950__9': 308, 'worker_count__10': 10, 'census_place_id__10': 30944, 'ind1950__10': 849, 'worker_count__11': 5, 'census_place_id__11': 30944, 'ind1950__11': 347, 'worker_count__12': 428, 'census_place_id__12': 31105, 'ind1950__12': 105, 'worker_count__13': 1, 'census_place_id__13': 31105, 'ind1950__13': 499, 'worker_count__14': 4, 'census_place_id__14': 31105, 'ind1950__14': 488, 'worker_count__15': 3, 'census_place_id__15': 31264, 'ind1950__15': 489, 'worker_count__16': 4, 'census_place_id__16': 31264 ... 2900 parameters truncated ... 'census_place_id__983': 26364, 'ind1950__983': 888, 'worker_count__984': 9, 'census_place_id__984': 26364, 'ind1950__984': 817, 'worker_count__985': 12, 'census_place_id__985': 26364, 'ind1950__985': 246, 'worker_count__986': 1, 'census_place_id__986': 26364, 'ind1950__986': 679, 'worker_count__987': 2, 'census_place_id__987': 26364, 'ind1950__987': 526, 'worker_count__988': 1, 'census_place_id__988': 26364, 'ind1950__988': 309, 'worker_count__989': 1, 'census_place_id__989': 26364, 'ind1950__989': 716, 'worker_count__990': 9, 'census_place_id__990': 26229, 'ind1950__990': 489, 'worker_count__991': 12, 'census_place_id__991': 26229, 'ind1950__991': 487, 'worker_count__992': 22, 'census_place_id__992': 26229, 'ind1950__992': 308, 'worker_count__993': 6, 'census_place_id__993': 26346, 'ind1950__993': 699, 'worker_count__994': 1, 'census_place_id__994': 26346, 'ind1950__994': 439, 'worker_count__995': 6, 'census_place_id__995': 25721, 'ind1950__995': 105, 'worker_count__996': 2, 'census_place_id__996': 25721, 'ind1950__996': 488, 'worker_count__997': 2, 'census_place_id__997': 26059, 'ind1950__997': 489, 'worker_count__998': 4, 'census_place_id__998': 19308, 'ind1950__998': 488, 'worker_count__999': 615, 'census_place_id__999': 19308, 'ind1950__999': 105}
# 2024-05-15 10:05:40,992 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 10:05:40,993 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/10 (unordered)] {'worker_count__0': 1, 'census_place_id__0': 19308, 'ind1950__0': 416, 'worker_count__1': 2, 'census_place_id__1': 19308, 'ind1950__1': 499, 'worker_count__2': 33, 'census_place_id__2': 27672, 'ind1950__2': 246, 'worker_count__3': 9, 'census_place_id__3': 27672, 'ind1950__3': 888, 'worker_count__4': 12, 'census_place_id__4': 27672, 'ind1950__4': 817, 'worker_count__5': 8, 'census_place_id__5': 27672, 'ind1950__5': 309, 'worker_count__6': 1, 'census_place_id__6': 27672, 'ind1950__6': 526, 'worker_count__7': 1, 'census_place_id__7': 27672, 'ind1950__7': 448, 'worker_count__8': 2, 'census_place_id__8': 28023, 'ind1950__8': 868, 'worker_count__9': 1, 'census_place_id__9': 28023, 'ind1950__9': 379, 'worker_count__10': 1, 'census_place_id__10': 27672, 'ind1950__10': 679, 'worker_count__11': 210, 'census_place_id__11': 27357, 'ind1950__11': 0, 'worker_count__12': 1, 'census_place_id__12': 27357, 'ind1950__12': 307, 'worker_count__13': 2, 'census_place_id__13': 27357, 'ind1950__13': 459, 'worker_count__14': 1, 'census_place_id__14': 27357, 'ind1950__14': 358, 'worker_count__15': 2, 'census_place_id__15': 27357, 'ind1950__15': 936, 'worker_count__16': 3032, 'census_place_id__16': 21725 ... 2900 parameters truncated ... 'census_place_id__983': 34551, 'ind1950__983': 316, 'worker_count__984': 48, 'census_place_id__984': 34551, 'ind1950__984': 105, 'worker_count__985': 1, 'census_place_id__985': 34551, 'ind1950__985': 899, 'worker_count__986': 1, 'census_place_id__986': 34551, 'ind1950__986': 926, 'worker_count__987': 1, 'census_place_id__987': 34551, 'ind1950__987': 906, 'worker_count__988': 3, 'census_place_id__988': 34551, 'ind1950__988': 697, 'worker_count__989': 1, 'census_place_id__989': 34551, 'ind1950__989': 658, 'worker_count__990': 17, 'census_place_id__990': 35274, 'ind1950__990': 246, 'worker_count__991': 14, 'census_place_id__991': 35274, 'ind1950__991': 817, 'worker_count__992': 3, 'census_place_id__992': 35274, 'ind1950__992': 309, 'worker_count__993': 1, 'census_place_id__993': 35274, 'ind1950__993': 526, 'worker_count__994': 2, 'census_place_id__994': 35274, 'ind1950__994': 888, 'worker_count__995': 172, 'census_place_id__995': 35596, 'ind1950__995': 105, 'worker_count__996': 2, 'census_place_id__996': 35596, 'ind1950__996': 488, 'worker_count__997': 754, 'census_place_id__997': 35737, 'ind1950__997': 0, 'worker_count__998': 2, 'census_place_id__998': 35737, 'ind1950__998': 836, 'worker_count__999': 1, 'census_place_id__999': 35749, 'ind1950__999': 656}
# 2024-05-15 10:05:40,999 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 10:05:41,000 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/10 (unordered)] {'worker_count__0': 3, 'census_place_id__0': 34647, 'ind1950__0': 656, 'worker_count__1': 1, 'census_place_id__1': 34647, 'ind1950__1': 669, 'worker_count__2': 172, 'census_place_id__2': 35345, 'ind1950__2': 105, 'worker_count__3': 7, 'census_place_id__3': 35345, 'ind1950__3': 488, 'worker_count__4': 1, 'census_place_id__4': 35345, 'ind1950__4': 906, 'worker_count__5': 9, 'census_place_id__5': 34793, 'ind1950__5': 246, 'worker_count__6': 1, 'census_place_id__6': 34793, 'ind1950__6': 448, 'worker_count__7': 6, 'census_place_id__7': 34793, 'ind1950__7': 817, 'worker_count__8': 1101, 'census_place_id__8': 34931, 'ind1950__8': 0, 'worker_count__9': 1, 'census_place_id__9': 35345, 'ind1950__9': 499, 'worker_count__10': 10, 'census_place_id__10': 34931, 'ind1950__10': 636, 'worker_count__11': 2, 'census_place_id__11': 34931, 'ind1950__11': 459, 'worker_count__12': 913, 'census_place_id__12': 34254, 'ind1950__12': 0, 'worker_count__13': 2, 'census_place_id__13': 34318, 'ind1950__13': 896, 'worker_count__14': 1, 'census_place_id__14': 34318, 'ind1950__14': 746, 'worker_count__15': 3, 'census_place_id__15': 34773, 'ind1950__15': 308, 'worker_count__16': 11, 'census_place_id__16': 34773 ... 2900 parameters truncated ... 'census_place_id__983': 45989, 'ind1950__983': 308, 'worker_count__984': 1, 'census_place_id__984': 45989, 'ind1950__984': 487, 'worker_count__985': 7, 'census_place_id__985': 46048, 'ind1950__985': 246, 'worker_count__986': 1, 'census_place_id__986': 46048, 'ind1950__986': 817, 'worker_count__987': 1, 'census_place_id__987': 46048, 'ind1950__987': 309, 'worker_count__988': 2, 'census_place_id__988': 46048, 'ind1950__988': 888, 'worker_count__989': 2, 'census_place_id__989': 45624, 'ind1950__989': 868, 'worker_count__990': 2, 'census_place_id__990': 45253, 'ind1950__990': 656, 'worker_count__991': 598, 'census_place_id__991': 45563, 'ind1950__991': 0, 'worker_count__992': 1, 'census_place_id__992': 45563, 'ind1950__992': 459, 'worker_count__993': 9, 'census_place_id__993': 45409, 'ind1950__993': 346, 'worker_count__994': 1, 'census_place_id__994': 45409, 'ind1950__994': 946, 'worker_count__995': 7, 'census_place_id__995': 45409, 'ind1950__995': 896, 'worker_count__996': 1, 'census_place_id__996': 45409, 'ind1950__996': 516, 'worker_count__997': 1, 'census_place_id__997': 45409, 'ind1950__997': 698, 'worker_count__998': 1, 'census_place_id__998': 45650, 'ind1950__998': 216, 'worker_count__999': 1, 'census_place_id__999': 45650, 'ind1950__999': 627}
# 2024-05-15 10:05:41,006 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 10:05:41,006 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/10 (unordered)] {'worker_count__0': 2, 'census_place_id__0': 46050, 'ind1950__0': 679, 'worker_count__1': 3, 'census_place_id__1': 46050, 'ind1950__1': 526, 'worker_count__2': 2, 'census_place_id__2': 46050, 'ind1950__2': 309, 'worker_count__3': 1, 'census_place_id__3': 46050, 'ind1950__3': 246, 'worker_count__4': 40, 'census_place_id__4': 45954, 'ind1950__4': 699, 'worker_count__5': 1, 'census_place_id__5': 45954, 'ind1950__5': 627, 'worker_count__6': 10, 'census_place_id__6': 45954, 'ind1950__6': 568, 'worker_count__7': 1, 'census_place_id__7': 45954, 'ind1950__7': 826, 'worker_count__8': 2, 'census_place_id__8': 45954, 'ind1950__8': 318, 'worker_count__9': 1, 'census_place_id__9': 45159, 'ind1950__9': 656, 'worker_count__10': 12, 'census_place_id__10': 45165, 'ind1950__10': 246, 'worker_count__11': 5, 'census_place_id__11': 45165, 'ind1950__11': 817, 'worker_count__12': 2, 'census_place_id__12': 45165, 'ind1950__12': 526, 'worker_count__13': 253, 'census_place_id__13': 44222, 'ind1950__13': 0, 'worker_count__14': 5, 'census_place_id__14': 27766, 'ind1950__14': 868, 'worker_count__15': 3, 'census_place_id__15': 27766, 'ind1950__15': 409, 'worker_count__16': 420, 'census_place_id__16': 27864 ... 2900 parameters truncated ... 'census_place_id__983': 48889, 'ind1950__983': 336, 'worker_count__984': 5, 'census_place_id__984': 49558, 'ind1950__984': 879, 'worker_count__985': 7, 'census_place_id__985': 49558, 'ind1950__985': 656, 'worker_count__986': 1, 'census_place_id__986': 49558, 'ind1950__986': 437, 'worker_count__987': 434, 'census_place_id__987': 49838, 'ind1950__987': 105, 'worker_count__988': 19, 'census_place_id__988': 49838, 'ind1950__988': 499, 'worker_count__989': 12, 'census_place_id__989': 49838, 'ind1950__989': 488, 'worker_count__990': 450, 'census_place_id__990': 49913, 'ind1950__990': 105, 'worker_count__991': 23, 'census_place_id__991': 49913, 'ind1950__991': 499, 'worker_count__992': 19, 'census_place_id__992': 49913, 'ind1950__992': 488, 'worker_count__993': 1, 'census_place_id__993': 49913, 'ind1950__993': 906, 'worker_count__994': 1, 'census_place_id__994': 49913, 'ind1950__994': 658, 'worker_count__995': 1, 'census_place_id__995': 50322, 'ind1950__995': 379, 'worker_count__996': 1, 'census_place_id__996': 50322, 'ind1950__996': 868, 'worker_count__997': 1461, 'census_place_id__997': 44296, 'ind1950__997': 0, 'worker_count__998': 1, 'census_place_id__998': 44296, 'ind1950__998': 636, 'worker_count__999': 1, 'census_place_id__999': 44296, 'ind1950__999': 459}
# 2024-05-15 10:05:41,013 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 10:05:41,013 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/10 (unordered)] {'worker_count__0': 3, 'census_place_id__0': 44296, 'ind1950__0': 358, 'worker_count__1': 1, 'census_place_id__1': 44296, 'ind1950__1': 836, 'worker_count__2': 1, 'census_place_id__2': 44296, 'ind1950__2': 936, 'worker_count__3': 3, 'census_place_id__3': 44883, 'ind1950__3': 346, 'worker_count__4': 1, 'census_place_id__4': 44883, 'ind1950__4': 896, 'worker_count__5': 1, 'census_place_id__5': 44883, 'ind1950__5': 746, 'worker_count__6': 2, 'census_place_id__6': 34529, 'ind1950__6': 379, 'worker_count__7': 2, 'census_place_id__7': 34529, 'ind1950__7': 868, 'worker_count__8': 1, 'census_place_id__8': 34529, 'ind1950__8': 409, 'worker_count__9': 5, 'census_place_id__9': 35984, 'ind1950__9': 699, 'worker_count__10': 1, 'census_place_id__10': 35984, 'ind1950__10': 568, 'worker_count__11': 13, 'census_place_id__11': 29620, 'ind1950__11': 308, 'worker_count__12': 6, 'census_place_id__12': 29620, 'ind1950__12': 489, 'worker_count__13': 8, 'census_place_id__13': 29620, 'ind1950__13': 546, 'worker_count__14': 3, 'census_place_id__14': 29620, 'ind1950__14': 487, 'worker_count__15': 2, 'census_place_id__15': 29620, 'ind1950__15': 849, 'worker_count__16': 1, 'census_place_id__16': 29620 ... 2900 parameters truncated ... 'census_place_id__983': 28778, 'ind1950__983': 399, 'worker_count__984': 2, 'census_place_id__984': 28778, 'ind1950__984': 346, 'worker_count__985': 71, 'census_place_id__985': 29513, 'ind1950__985': 546, 'worker_count__986': 41, 'census_place_id__986': 29513, 'ind1950__986': 308, 'worker_count__987': 8, 'census_place_id__987': 29513, 'ind1950__987': 849, 'worker_count__988': 2, 'census_place_id__988': 28778, 'ind1950__988': 516, 'worker_count__989': 22, 'census_place_id__989': 29513, 'ind1950__989': 489, 'worker_count__990': 5, 'census_place_id__990': 29513, 'ind1950__990': 487, 'worker_count__991': 991, 'census_place_id__991': 20314, 'ind1950__991': 105, 'worker_count__992': 17, 'census_place_id__992': 20314, 'ind1950__992': 488, 'worker_count__993': 4, 'census_place_id__993': 20314, 'ind1950__993': 499, 'worker_count__994': 3, 'census_place_id__994': 20314, 'ind1950__994': 906, 'worker_count__995': 1, 'census_place_id__995': 29513, 'ind1950__995': 637, 'worker_count__996': 1, 'census_place_id__996': 20314, 'ind1950__996': 926, 'worker_count__997': 3, 'census_place_id__997': 6443, 'ind1950__997': 879, 'worker_count__998': 1, 'census_place_id__998': 1337, 'ind1950__998': 419, 'worker_count__999': 2, 'census_place_id__999': 1337, 'ind1950__999': 868}
# 2024-05-15 10:05:41,019 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 10:05:41,020 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/10 (unordered)] {'worker_count__0': 2, 'census_place_id__0': 2687, 'ind1950__0': 656, 'worker_count__1': 669, 'census_place_id__1': 47675, 'ind1950__1': 546, 'worker_count__2': 9, 'census_place_id__2': 47675, 'ind1950__2': 308, 'worker_count__3': 2, 'census_place_id__3': 47675, 'ind1950__3': 916, 'worker_count__4': 5, 'census_place_id__4': 47106, 'ind1950__4': 896, 'worker_count__5': 7, 'census_place_id__5': 47106, 'ind1950__5': 449, 'worker_count__6': 1, 'census_place_id__6': 47106, 'ind1950__6': 946, 'worker_count__7': 1, 'census_place_id__7': 46596, 'ind1950__7': 896, 'worker_count__8': 1, 'census_place_id__8': 46384, 'ind1950__8': 469, 'worker_count__9': 2, 'census_place_id__9': 46384, 'ind1950__9': 656, 'worker_count__10': 1, 'census_place_id__10': 46384, 'ind1950__10': 879, 'worker_count__11': 6, 'census_place_id__11': 46226, 'ind1950__11': 896, 'worker_count__12': 1, 'census_place_id__12': 46226, 'ind1950__12': 346, 'worker_count__13': 5, 'census_place_id__13': 45843, 'ind1950__13': 896, 'worker_count__14': 3, 'census_place_id__14': 45843, 'ind1950__14': 449, 'worker_count__15': 1, 'census_place_id__15': 45843, 'ind1950__15': 346, 'worker_count__16': 3, 'census_place_id__16': 45827 ... 2900 parameters truncated ... 'census_place_id__983': 36420, 'ind1950__983': 309, 'worker_count__984': 2, 'census_place_id__984': 43587, 'ind1950__984': 416, 'worker_count__985': 3, 'census_place_id__985': 43587, 'ind1950__985': 499, 'worker_count__986': 3, 'census_place_id__986': 43197, 'ind1950__986': 879, 'worker_count__987': 548, 'census_place_id__987': 43694, 'ind1950__987': 0, 'worker_count__988': 1, 'census_place_id__988': 43694, 'ind1950__988': 636, 'worker_count__989': 294, 'census_place_id__989': 43795, 'ind1950__989': 0, 'worker_count__990': 2, 'census_place_id__990': 44181, 'ind1950__990': 896, 'worker_count__991': 14, 'census_place_id__991': 44396, 'ind1950__991': 105, 'worker_count__992': 2, 'census_place_id__992': 44396, 'ind1950__992': 488, 'worker_count__993': 3, 'census_place_id__993': 43692, 'ind1950__993': 246, 'worker_count__994': 1, 'census_place_id__994': 43692, 'ind1950__994': 888, 'worker_count__995': 1, 'census_place_id__995': 43692, 'ind1950__995': 309, 'worker_count__996': 1, 'census_place_id__996': 43692, 'ind1950__996': 817, 'worker_count__997': 327, 'census_place_id__997': 44177, 'ind1950__997': 0, 'worker_count__998': 2, 'census_place_id__998': 44172, 'ind1950__998': 699, 'worker_count__999': 1, 'census_place_id__999': 43662, 'ind1950__999': 888}
# 2024-05-15 10:05:41,026 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 10:05:41,026 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/10 (unordered)] {'worker_count__0': 3, 'census_place_id__0': 43662, 'ind1950__0': 246, 'worker_count__1': 1, 'census_place_id__1': 43662, 'ind1950__1': 309, 'worker_count__2': 16, 'census_place_id__2': 36692, 'ind1950__2': 817, 'worker_count__3': 6, 'census_place_id__3': 36692, 'ind1950__3': 309, 'worker_count__4': 3, 'census_place_id__4': 36692, 'ind1950__4': 679, 'worker_count__5': 26, 'census_place_id__5': 36692, 'ind1950__5': 246, 'worker_count__6': 1, 'census_place_id__6': 36692, 'ind1950__6': 526, 'worker_count__7': 3, 'census_place_id__7': 36692, 'ind1950__7': 888, 'worker_count__8': 2, 'census_place_id__8': 43662, 'ind1950__8': 817, 'worker_count__9': 2, 'census_place_id__9': 36118, 'ind1950__9': 309, 'worker_count__10': 10, 'census_place_id__10': 36118, 'ind1950__10': 246, 'worker_count__11': 7, 'census_place_id__11': 36118, 'ind1950__11': 817, 'worker_count__12': 2, 'census_place_id__12': 36118, 'ind1950__12': 679, 'worker_count__13': 1, 'census_place_id__13': 35952, 'ind1950__13': 487, 'worker_count__14': 1, 'census_place_id__14': 35952, 'ind1950__14': 489, 'worker_count__15': 2, 'census_place_id__15': 35952, 'ind1950__15': 308, 'worker_count__16': 2, 'census_place_id__16': 36531 ... 2900 parameters truncated ... 'census_place_id__983': 35524, 'ind1950__983': 896, 'worker_count__984': 1, 'census_place_id__984': 35524, 'ind1950__984': 399, 'worker_count__985': 5, 'census_place_id__985': 34346, 'ind1950__985': 656, 'worker_count__986': 1, 'census_place_id__986': 34351, 'ind1950__986': 879, 'worker_count__987': 2, 'census_place_id__987': 34351, 'ind1950__987': 656, 'worker_count__988': 405, 'census_place_id__988': 34368, 'ind1950__988': 105, 'worker_count__989': 10, 'census_place_id__989': 34368, 'ind1950__989': 488, 'worker_count__990': 1, 'census_place_id__990': 34368, 'ind1950__990': 499, 'worker_count__991': 5, 'census_place_id__991': 34973, 'ind1950__991': 439, 'worker_count__992': 9, 'census_place_id__992': 34973, 'ind1950__992': 699, 'worker_count__993': 307, 'census_place_id__993': 35508, 'ind1950__993': 105, 'worker_count__994': 2, 'census_place_id__994': 35508, 'ind1950__994': 499, 'worker_count__995': 2, 'census_place_id__995': 35508, 'ind1950__995': 488, 'worker_count__996': 3, 'census_place_id__996': 31603, 'ind1950__996': 868, 'worker_count__997': 268, 'census_place_id__997': 31390, 'ind1950__997': 0, 'worker_count__998': 1, 'census_place_id__998': 31390, 'ind1950__998': 836, 'worker_count__999': 256, 'census_place_id__999': 31013, 'ind1950__999': 0}
# 2024-05-15 10:05:41,032 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 10:05:41,041 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 10:05:41,041 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-05-15 10:05:41,042 INFO sqlalchemy.engine.Engine [cached since 34.19s ago] {'table_name': 'census_place_industry_count_1850', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-05-15 10:05:41,083 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 10:05:41,084 INFO sqlalchemy.engine.Engine [generated in 0.00911s (insertmanyvalues) 1/10 (unordered)] {'worker_count__0': 1, 'census_place_id__0': 31270, 'ind1950__0': 409, 'worker_count__1': 2, 'census_place_id__1': 31270, 'ind1950__1': 379, 'worker_count__2': 159, 'census_place_id__2': 31486, 'ind1950__2': 105, 'worker_count__3': 1, 'census_place_id__3': 31486, 'ind1950__3': 499, 'worker_count__4': 1, 'census_place_id__4': 32305, 'ind1950__4': 888, 'worker_count__5': 5, 'census_place_id__5': 32305, 'ind1950__5': 246, 'worker_count__6': 4, 'census_place_id__6': 32305, 'ind1950__6': 817, 'worker_count__7': 1, 'census_place_id__7': 31486, 'ind1950__7': 488, 'worker_count__8': 4, 'census_place_id__8': 32358, 'ind1950__8': 346, 'worker_count__9': 2, 'census_place_id__9': 32358, 'ind1950__9': 399, 'worker_count__10': 1, 'census_place_id__10': 32358, 'ind1950__10': 896, 'worker_count__11': 5, 'census_place_id__11': 32038, 'ind1950__11': 246, 'worker_count__12': 5, 'census_place_id__12': 32038, 'ind1950__12': 817, 'worker_count__13': 3, 'census_place_id__13': 32038, 'ind1950__13': 309, 'worker_count__14': 256, 'census_place_id__14': 31945, 'ind1950__14': 105, 'worker_count__15': 1, 'census_place_id__15': 31945, 'ind1950__15': 488, 'worker_count__16': 1, 'census_place_id__16': 32038 ... 2900 parameters truncated ... 'census_place_id__983': 34004, 'ind1950__983': 439, 'worker_count__984': 3, 'census_place_id__984': 34298, 'ind1950__984': 308, 'worker_count__985': 7, 'census_place_id__985': 34541, 'ind1950__985': 346, 'worker_count__986': 2, 'census_place_id__986': 34541, 'ind1950__986': 399, 'worker_count__987': 135, 'census_place_id__987': 34589, 'ind1950__987': 105, 'worker_count__988': 1, 'census_place_id__988': 34541, 'ind1950__988': 896, 'worker_count__989': 6, 'census_place_id__989': 34589, 'ind1950__989': 488, 'worker_count__990': 2, 'census_place_id__990': 34492, 'ind1950__990': 868, 'worker_count__991': 22, 'census_place_id__991': 33401, 'ind1950__991': 246, 'worker_count__992': 9, 'census_place_id__992': 33401, 'ind1950__992': 817, 'worker_count__993': 1, 'census_place_id__993': 33401, 'ind1950__993': 888, 'worker_count__994': 1, 'census_place_id__994': 33282, 'ind1950__994': 346, 'worker_count__995': 1, 'census_place_id__995': 33282, 'ind1950__995': 896, 'worker_count__996': 1, 'census_place_id__996': 33282, 'ind1950__996': 516, 'worker_count__997': 539, 'census_place_id__997': 33218, 'ind1950__997': 0, 'worker_count__998': 2, 'census_place_id__998': 33218, 'ind1950__998': 358, 'worker_count__999': 786, 'census_place_id__999': 33350, 'ind1950__999': 0}
# 2024-05-15 10:05:41,090 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 10:05:41,091 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/10 (unordered)] {'worker_count__0': 4, 'census_place_id__0': 33350, 'ind1950__0': 636, 'worker_count__1': 3, 'census_place_id__1': 33644, 'ind1950__1': 888, 'worker_count__2': 10, 'census_place_id__2': 33644, 'ind1950__2': 246, 'worker_count__3': 3, 'census_place_id__3': 33644, 'ind1950__3': 817, 'worker_count__4': 1, 'census_place_id__4': 33699, 'ind1950__4': 308, 'worker_count__5': 26, 'census_place_id__5': 33206, 'ind1950__5': 246, 'worker_count__6': 12, 'census_place_id__6': 33206, 'ind1950__6': 817, 'worker_count__7': 1, 'census_place_id__7': 33206, 'ind1950__7': 448, 'worker_count__8': 2, 'census_place_id__8': 33206, 'ind1950__8': 309, 'worker_count__9': 1, 'census_place_id__9': 33206, 'ind1950__9': 319, 'worker_count__10': 248, 'census_place_id__10': 34130, 'ind1950__10': 105, 'worker_count__11': 8, 'census_place_id__11': 34130, 'ind1950__11': 488, 'worker_count__12': 1, 'census_place_id__12': 34322, 'ind1950__12': 409, 'worker_count__13': 3, 'census_place_id__13': 34322, 'ind1950__13': 379, 'worker_count__14': 1, 'census_place_id__14': 34322, 'ind1950__14': 868, 'worker_count__15': 2, 'census_place_id__15': 34173, 'ind1950__15': 699, 'worker_count__16': 1, 'census_place_id__16': 34173 ... 2900 parameters truncated ... 'census_place_id__983': 50692, 'ind1950__983': 656, 'worker_count__984': 2, 'census_place_id__984': 50692, 'ind1950__984': 879, 'worker_count__985': 1, 'census_place_id__985': 50692, 'ind1950__985': 437, 'worker_count__986': 2, 'census_place_id__986': 50692, 'ind1950__986': 669, 'worker_count__987': 1, 'census_place_id__987': 50692, 'ind1950__987': 469, 'worker_count__988': 6, 'census_place_id__988': 50288, 'ind1950__988': 308, 'worker_count__989': 25, 'census_place_id__989': 50288, 'ind1950__989': 546, 'worker_count__990': 1, 'census_place_id__990': 50288, 'ind1950__990': 489, 'worker_count__991': 4, 'census_place_id__991': 50288, 'ind1950__991': 487, 'worker_count__992': 178, 'census_place_id__992': 50186, 'ind1950__992': 488, 'worker_count__993': 76, 'census_place_id__993': 50186, 'ind1950__993': 105, 'worker_count__994': 4, 'census_place_id__994': 50307, 'ind1950__994': 699, 'worker_count__995': 20, 'census_place_id__995': 50307, 'ind1950__995': 439, 'worker_count__996': 2, 'census_place_id__996': 50408, 'ind1950__996': 388, 'worker_count__997': 4, 'census_place_id__997': 50408, 'ind1950__997': 716, 'worker_count__998': 127, 'census_place_id__998': 50408, 'ind1950__998': 246, 'worker_count__999': 6, 'census_place_id__999': 50408, 'ind1950__999': 526}
# 2024-05-15 10:05:41,097 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 10:05:41,097 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/10 (unordered)] {'worker_count__0': 11, 'census_place_id__0': 50408, 'ind1950__0': 309, 'worker_count__1': 44, 'census_place_id__1': 50408, 'ind1950__1': 817, 'worker_count__2': 5, 'census_place_id__2': 50408, 'ind1950__2': 336, 'worker_count__3': 2, 'census_place_id__3': 50408, 'ind1950__3': 898, 'worker_count__4': 21, 'census_place_id__4': 50408, 'ind1950__4': 888, 'worker_count__5': 3, 'census_place_id__5': 50408, 'ind1950__5': 448, 'worker_count__6': 15, 'census_place_id__6': 50408, 'ind1950__6': 337, 'worker_count__7': 1, 'census_place_id__7': 50408, 'ind1950__7': 808, 'worker_count__8': 1, 'census_place_id__8': 50408, 'ind1950__8': 319, 'worker_count__9': 2, 'census_place_id__9': 50418, 'ind1950__9': 326, 'worker_count__10': 1, 'census_place_id__10': 50418, 'ind1950__10': 409, 'worker_count__11': 30, 'census_place_id__11': 50479, 'ind1950__11': 699, 'worker_count__12': 17, 'census_place_id__12': 50479, 'ind1950__12': 439, 'worker_count__13': 1, 'census_place_id__13': 50479, 'ind1950__13': 386, 'worker_count__14': 1, 'census_place_id__14': 50479, 'ind1950__14': 568, 'worker_count__15': 2, 'census_place_id__15': 50479, 'ind1950__15': 318, 'worker_count__16': 5, 'census_place_id__16': 50647 ... 2900 parameters truncated ... 'census_place_id__983': 37281, 'ind1950__983': 439, 'worker_count__984': 8, 'census_place_id__984': 37281, 'ind1950__984': 699, 'worker_count__985': 1, 'census_place_id__985': 37750, 'ind1950__985': 896, 'worker_count__986': 851, 'census_place_id__986': 37200, 'ind1950__986': 0, 'worker_count__987': 2, 'census_place_id__987': 36672, 'ind1950__987': 699, 'worker_count__988': 1, 'census_place_id__988': 36351, 'ind1950__988': 546, 'worker_count__989': 180, 'census_place_id__989': 36655, 'ind1950__989': 105, 'worker_count__990': 4, 'census_place_id__990': 36655, 'ind1950__990': 488, 'worker_count__991': 13, 'census_place_id__991': 37739, 'ind1950__991': 699, 'worker_count__992': 1, 'census_place_id__992': 37739, 'ind1950__992': 439, 'worker_count__993': 16, 'census_place_id__993': 37181, 'ind1950__993': 246, 'worker_count__994': 2, 'census_place_id__994': 37181, 'ind1950__994': 817, 'worker_count__995': 2, 'census_place_id__995': 41613, 'ind1950__995': 308, 'worker_count__996': 977, 'census_place_id__996': 40996, 'ind1950__996': 0, 'worker_count__997': 1, 'census_place_id__997': 39911, 'ind1950__997': 896, 'worker_count__998': 15, 'census_place_id__998': 40043, 'ind1950__998': 699, 'worker_count__999': 1, 'census_place_id__999': 40043, 'ind1950__999': 439}
# 2024-05-15 10:05:41,103 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 10:05:41,103 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/10 (unordered)] {'worker_count__0': 1, 'census_place_id__0': 40043, 'ind1950__0': 568, 'worker_count__1': 1, 'census_place_id__1': 40043, 'ind1950__1': 318, 'worker_count__2': 1, 'census_place_id__2': 40971, 'ind1950__2': 656, 'worker_count__3': 5, 'census_place_id__3': 41023, 'ind1950__3': 699, 'worker_count__4': 3, 'census_place_id__4': 41023, 'ind1950__4': 439, 'worker_count__5': 2, 'census_place_id__5': 40610, 'ind1950__5': 568, 'worker_count__6': 8, 'census_place_id__6': 42422, 'ind1950__6': 379, 'worker_count__7': 5, 'census_place_id__7': 42422, 'ind1950__7': 326, 'worker_count__8': 1, 'census_place_id__8': 42422, 'ind1950__8': 857, 'worker_count__9': 136, 'census_place_id__9': 42345, 'ind1950__9': 105, 'worker_count__10': 1, 'census_place_id__10': 42345, 'ind1950__10': 499, 'worker_count__11': 3, 'census_place_id__11': 42345, 'ind1950__11': 488, 'worker_count__12': 40, 'census_place_id__12': 43380, 'ind1950__12': 246, 'worker_count__13': 1, 'census_place_id__13': 43380, 'ind1950__13': 448, 'worker_count__14': 13, 'census_place_id__14': 43380, 'ind1950__14': 817, 'worker_count__15': 1, 'census_place_id__15': 43380, 'ind1950__15': 679, 'worker_count__16': 1, 'census_place_id__16': 43380 ... 2900 parameters truncated ... 'census_place_id__983': 36216, 'ind1950__983': 896, 'worker_count__984': 3, 'census_place_id__984': 35511, 'ind1950__984': 868, 'worker_count__985': 5, 'census_place_id__985': 35511, 'ind1950__985': 409, 'worker_count__986': 121, 'census_place_id__986': 36942, 'ind1950__986': 105, 'worker_count__987': 10, 'census_place_id__987': 36836, 'ind1950__987': 817, 'worker_count__988': 73, 'census_place_id__988': 36836, 'ind1950__988': 246, 'worker_count__989': 4, 'census_place_id__989': 36836, 'ind1950__989': 888, 'worker_count__990': 7, 'census_place_id__990': 36836, 'ind1950__990': 309, 'worker_count__991': 6, 'census_place_id__991': 36836, 'ind1950__991': 527, 'worker_count__992': 2, 'census_place_id__992': 36836, 'ind1950__992': 337, 'worker_count__993': 3, 'census_place_id__993': 36836, 'ind1950__993': 378, 'worker_count__994': 1, 'census_place_id__994': 36836, 'ind1950__994': 319, 'worker_count__995': 2, 'census_place_id__995': 36836, 'ind1950__995': 526, 'worker_count__996': 1, 'census_place_id__996': 36836, 'ind1950__996': 579, 'worker_count__997': 1, 'census_place_id__997': 36836, 'ind1950__997': 679, 'worker_count__998': 2, 'census_place_id__998': 31896, 'ind1950__998': 896, 'worker_count__999': 1, 'census_place_id__999': 31806, 'ind1950__999': 699}
# 2024-05-15 10:05:41,110 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# ...
# 2024-05-15 10:05:48,583 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/10 (unordered)] {'worker_count__0': 1, 'census_place_id__0': 18806, 'ind1950__0': 379, 'worker_count__1': 9, 'census_place_id__1': 19384, 'ind1950__1': 246, 'worker_count__2': 12, 'census_place_id__2': 19384, 'ind1950__2': 817, 'worker_count__3': 1, 'census_place_id__3': 19384, 'ind1950__3': 526, 'worker_count__4': 1, 'census_place_id__4': 19384, 'ind1950__4': 888, 'worker_count__5': 1, 'census_place_id__5': 19384, 'ind1950__5': 309, 'worker_count__6': 200, 'census_place_id__6': 18802, 'ind1950__6': 826, 'worker_count__7': 1, 'census_place_id__7': 18802, 'ind1950__7': 439, 'worker_count__8': 2, 'census_place_id__8': 18802, 'ind1950__8': 699, 'worker_count__9': 1093, 'census_place_id__9': 19226, 'ind1950__9': 0, 'worker_count__10': 23, 'census_place_id__10': 19226, 'ind1950__10': 997, 'worker_count__11': 1, 'census_place_id__11': 19226, 'ind1950__11': 358, 'worker_count__12': 1, 'census_place_id__12': 19226, 'ind1950__12': 936, 'worker_count__13': 4, 'census_place_id__13': 18988, 'ind1950__13': 409, 'worker_count__14': 5, 'census_place_id__14': 18988, 'ind1950__14': 379, 'worker_count__15': 1, 'census_place_id__15': 19197, 'ind1950__15': 698, 'worker_count__16': 2, 'census_place_id__16': 18690 ... 2900 parameters truncated ... 'census_place_id__983': 48514, 'ind1950__983': 399, 'worker_count__984': 1, 'census_place_id__984': 48514, 'ind1950__984': 346, 'worker_count__985': 3, 'census_place_id__985': 48158, 'ind1950__985': 488, 'worker_count__986': 95, 'census_place_id__986': 48209, 'ind1950__986': 105, 'worker_count__987': 1, 'census_place_id__987': 48209, 'ind1950__987': 488, 'worker_count__988': 1, 'census_place_id__988': 48394, 'ind1950__988': 488, 'worker_count__989': 3, 'census_place_id__989': 48921, 'ind1950__989': 379, 'worker_count__990': 3, 'census_place_id__990': 49058, 'ind1950__990': 826, 'worker_count__991': 1, 'census_place_id__991': 48731, 'ind1950__991': 308, 'worker_count__992': 1, 'census_place_id__992': 49058, 'ind1950__992': 699, 'worker_count__993': 1, 'census_place_id__993': 48921, 'ind1950__993': 506, 'worker_count__994': 2, 'census_place_id__994': 49220, 'ind1950__994': 488, 'worker_count__995': 80, 'census_place_id__995': 49220, 'ind1950__995': 105, 'worker_count__996': 3, 'census_place_id__996': 48921, 'ind1950__996': 868, 'worker_count__997': 2, 'census_place_id__997': 48921, 'ind1950__997': 409, 'worker_count__998': 2, 'census_place_id__998': 49498, 'ind1950__998': 409, 'worker_count__999': 2, 'census_place_id__999': 49498, 'ind1950__999': 379}
# 2024-05-15 10:05:48,593 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1860 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 10:05:48,593 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/10 (unordered)] {'worker_count__0': 3, 'census_place_id__0': 48921, 'ind1950__0': 726, 'worker_count__1': 1, 'census_place_id__1': 49498, 'ind1950__1': 868, 'worker_count__2': 212, 'census_place_id__2': 49603, 'ind1950__2': 105, 'worker_count__3': 1, 'census_place_id__3': 49603, 'ind1950__3': 499, 'worker_count__4': 1, 'census_place_id__4': 49603, 'ind1950__4': 899, 'worker_count__5': 11, 'census_place_id__5': 49603, 'ind1950__5': 488, 'worker_count__6': 1, 'census_place_id__6': 49576, 'ind1950__6': 246, 'worker_count__7': 1, 'census_place_id__7': 49576, 'ind1950__7': 888, 'worker_count__8': 1, 'census_place_id__8': 49516, 'ind1950__8': 656, 'worker_count__9': 11, 'census_place_id__9': 49332, 'ind1950__9': 826, 'worker_count__10': 9, 'census_place_id__10': 49332, 'ind1950__10': 699, 'worker_count__11': 7, 'census_place_id__11': 49439, 'ind1950__11': 997, 'worker_count__12': 220, 'census_place_id__12': 49439, 'ind1950__12': 0, 'worker_count__13': 2, 'census_place_id__13': 49297, 'ind1950__13': 409, 'worker_count__14': 1, 'census_place_id__14': 49297, 'ind1950__14': 868, 'worker_count__15': 1, 'census_place_id__15': 49297, 'ind1950__15': 726, 'worker_count__16': 2, 'census_place_id__16': 49439 ... 2900 parameters truncated ... 'census_place_id__983': 19289, 'ind1950__983': 105, 'worker_count__984': 1, 'census_place_id__984': 19289, 'ind1950__984': 499, 'worker_count__985': 241, 'census_place_id__985': 19614, 'ind1950__985': 105, 'worker_count__986': 7, 'census_place_id__986': 20176, 'ind1950__986': 246, 'worker_count__987': 9, 'census_place_id__987': 20176, 'ind1950__987': 817, 'worker_count__988': 2, 'census_place_id__988': 20176, 'ind1950__988': 888, 'worker_count__989': 1, 'census_place_id__989': 20176, 'ind1950__989': 309, 'worker_count__990': 7, 'census_place_id__990': 19994, 'ind1950__990': 826, 'worker_count__991': 2, 'census_place_id__991': 19614, 'ind1950__991': 488, 'worker_count__992': 2, 'census_place_id__992': 19614, 'ind1950__992': 499, 'worker_count__993': 1, 'census_place_id__993': 19614, 'ind1950__993': 658, 'worker_count__994': 224, 'census_place_id__994': 19943, 'ind1950__994': 0, 'worker_count__995': 1, 'census_place_id__995': 22585, 'ind1950__995': 656, 'worker_count__996': 2, 'census_place_id__996': 23003, 'ind1950__996': 826, 'worker_count__997': 5, 'census_place_id__997': 22585, 'ind1950__997': 879, 'worker_count__998': 1, 'census_place_id__998': 24859, 'ind1950__998': 409, 'worker_count__999': 3, 'census_place_id__999': 25631, 'ind1950__999': 868}
# 2024-05-15 10:05:48,603 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 10:05:48,608 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 10:05:48,608 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-05-15 10:05:48,609 INFO sqlalchemy.engine.Engine [cached since 41.76s ago] {'table_name': 'census_place_industry_count_1860', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-05-15 10:05:48,614 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1860 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 10:05:48,614 INFO sqlalchemy.engine.Engine [generated in 0.00206s (insertmanyvalues) 1/3 (unordered)] {'worker_count__0': 1, 'census_place_id__0': 25631, 'ind1950__0': 409, 'worker_count__1': 2, 'census_place_id__1': 25631, 'ind1950__1': 379, 'worker_count__2': 15, 'census_place_id__2': 26038, 'ind1950__2': 699, 'worker_count__3': 3, 'census_place_id__3': 26038, 'ind1950__3': 826, 'worker_count__4': 1, 'census_place_id__4': 26038, 'ind1950__4': 216, 'worker_count__5': 668, 'census_place_id__5': 25288, 'ind1950__5': 0, 'worker_count__6': 1, 'census_place_id__6': 25288, 'ind1950__6': 636, 'worker_count__7': 1, 'census_place_id__7': 26414, 'ind1950__7': 246, 'worker_count__8': 80, 'census_place_id__8': 26413, 'ind1950__8': 105, 'worker_count__9': 60, 'census_place_id__9': 26509, 'ind1950__9': 0, 'worker_count__10': 2, 'census_place_id__10': 26414, 'ind1950__10': 888, 'worker_count__11': 1, 'census_place_id__11': 26414, 'ind1950__11': 817, 'worker_count__12': 2, 'census_place_id__12': 25841, 'ind1950__12': 488, 'worker_count__13': 6437, 'census_place_id__13': 25559, 'ind1950__13': 0, 'worker_count__14': 254, 'census_place_id__14': 25559, 'ind1950__14': 997, 'worker_count__15': 7, 'census_place_id__15': 25559, 'ind1950__15': 836, 'worker_count__16': 3, 'census_place_id__16': 25559 ... 2900 parameters truncated ... 'census_place_id__983': 30989, 'ind1950__983': 847, 'worker_count__984': 1, 'census_place_id__984': 40518, 'ind1950__984': 388, 'worker_count__985': 7, 'census_place_id__985': 40518, 'ind1950__985': 309, 'worker_count__986': 4, 'census_place_id__986': 40518, 'ind1950__986': 808, 'worker_count__987': 1, 'census_place_id__987': 40518, 'ind1950__987': 448, 'worker_count__988': 1, 'census_place_id__988': 40518, 'ind1950__988': 527, 'worker_count__989': 2, 'census_place_id__989': 40518, 'ind1950__989': 378, 'worker_count__990': 1, 'census_place_id__990': 40518, 'ind1950__990': 579, 'worker_count__991': 2, 'census_place_id__991': 40387, 'ind1950__991': 439, 'worker_count__992': 28, 'census_place_id__992': 40387, 'ind1950__992': 216, 'worker_count__993': 2, 'census_place_id__993': 40507, 'ind1950__993': 216, 'worker_count__994': 2, 'census_place_id__994': 40387, 'ind1950__994': 699, 'worker_count__995': 10, 'census_place_id__995': 40387, 'ind1950__995': 826, 'worker_count__996': 2, 'census_place_id__996': 41590, 'ind1950__996': 216, 'worker_count__997': 48, 'census_place_id__997': 41590, 'ind1950__997': 826, 'worker_count__998': 33, 'census_place_id__998': 41434, 'ind1950__998': 826, 'worker_count__999': 3, 'census_place_id__999': 41434, 'ind1950__999': 699}
# 2024-05-15 10:05:48,625 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1860 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 10:05:48,625 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/3 (unordered)] {'worker_count__0': 1, 'census_place_id__0': 41434, 'ind1950__0': 216, 'worker_count__1': 1, 'census_place_id__1': 41434, 'ind1950__1': 439, 'worker_count__2': 10, 'census_place_id__2': 41298, 'ind1950__2': 246, 'worker_count__3': 1, 'census_place_id__3': 41298, 'ind1950__3': 526, 'worker_count__4': 1, 'census_place_id__4': 41298, 'ind1950__4': 817, 'worker_count__5': 1, 'census_place_id__5': 41742, 'ind1950__5': 656, 'worker_count__6': 8, 'census_place_id__6': 41590, 'ind1950__6': 699, 'worker_count__7': 1, 'census_place_id__7': 41590, 'ind1950__7': 439, 'worker_count__8': 316, 'census_place_id__8': 40731, 'ind1950__8': 105, 'worker_count__9': 17, 'census_place_id__9': 40731, 'ind1950__9': 488, 'worker_count__10': 2, 'census_place_id__10': 39576, 'ind1950__10': 105, 'worker_count__11': 2, 'census_place_id__11': 39576, 'ind1950__11': 488, 'worker_count__12': 1, 'census_place_id__12': 40542, 'ind1950__12': 898, 'worker_count__13': 18, 'census_place_id__13': 39581, 'ind1950__13': 246, 'worker_count__14': 6, 'census_place_id__14': 39581, 'ind1950__14': 888, 'worker_count__15': 2, 'census_place_id__15': 39581, 'ind1950__15': 817, 'worker_count__16': 1, 'census_place_id__16': 39581 ... 2900 parameters truncated ... 'census_place_id__983': 50914, 'ind1950__983': 526, 'worker_count__984': 1, 'census_place_id__984': 50914, 'ind1950__984': 579, 'worker_count__985': 2, 'census_place_id__985': 50270, 'ind1950__985': 379, 'worker_count__986': 1, 'census_place_id__986': 50448, 'ind1950__986': 936, 'worker_count__987': 1, 'census_place_id__987': 50448, 'ind1950__987': 836, 'worker_count__988': 1, 'census_place_id__988': 50448, 'ind1950__988': 636, 'worker_count__989': 2, 'census_place_id__989': 50321, 'ind1950__989': 409, 'worker_count__990': 2, 'census_place_id__990': 50321, 'ind1950__990': 506, 'worker_count__991': 1, 'census_place_id__991': 50321, 'ind1950__991': 868, 'worker_count__992': 7, 'census_place_id__992': 51162, 'ind1950__992': 246, 'worker_count__993': 2, 'census_place_id__993': 51162, 'ind1950__993': 817, 'worker_count__994': 3, 'census_place_id__994': 51162, 'ind1950__994': 888, 'worker_count__995': 51, 'census_place_id__995': 50181, 'ind1950__995': 105, 'worker_count__996': 1, 'census_place_id__996': 50181, 'ind1950__996': 906, 'worker_count__997': 1, 'census_place_id__997': 51162, 'ind1950__997': 597, 'worker_count__998': 3, 'census_place_id__998': 50270, 'ind1950__998': 868, 'worker_count__999': 1, 'census_place_id__999': 50270, 'ind1950__999': 506}
# 2024-05-15 10:05:48,634 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1860 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 14246 characters truncated ... __213)s, %(worker_count__213)s), (%(census_place_id__214)s, %(ind1950__214)s, %(worker_count__214)s)
# 2024-05-15 10:05:48,634 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/3 (unordered)] {'worker_count__0': 1, 'census_place_id__0': 50020, 'ind1950__0': 656, 'worker_count__1': 2, 'census_place_id__1': 50020, 'ind1950__1': 879, 'worker_count__2': 18, 'census_place_id__2': 49888, 'ind1950__2': 0, 'worker_count__3': 5, 'census_place_id__3': 51118, 'ind1950__3': 888, 'worker_count__4': 3, 'census_place_id__4': 51118, 'ind1950__4': 246, 'worker_count__5': 1, 'census_place_id__5': 51118, 'ind1950__5': 309, 'worker_count__6': 5, 'census_place_id__6': 51118, 'ind1950__6': 817, 'worker_count__7': 2, 'census_place_id__7': 50950, 'ind1950__7': 489, 'worker_count__8': 5, 'census_place_id__8': 50491, 'ind1950__8': 439, 'worker_count__9': 1, 'census_place_id__9': 20465, 'ind1950__9': 896, 'worker_count__10': 1, 'census_place_id__10': 21331, 'ind1950__10': 817, 'worker_count__11': 1, 'census_place_id__11': 20341, 'ind1950__11': 898, 'worker_count__12': 1, 'census_place_id__12': 50491, 'ind1950__12': 406, 'worker_count__13': 1, 'census_place_id__13': 54336, 'ind1950__13': 699, 'worker_count__14': 8, 'census_place_id__14': 54336, 'ind1950__14': 826, 'worker_count__15': 25, 'census_place_id__15': 54902, 'ind1950__15': 997, 'worker_count__16': 1490, 'census_place_id__16': 54902 ... 545 parameters truncated ... 'census_place_id__198': 51602, 'ind1950__198': 997, 'worker_count__199': 17, 'census_place_id__199': 51797, 'ind1950__199': 826, 'worker_count__200': 2, 'census_place_id__200': 51797, 'ind1950__200': 699, 'worker_count__201': 12, 'census_place_id__201': 52267, 'ind1950__201': 246, 'worker_count__202': 3, 'census_place_id__202': 52267, 'ind1950__202': 817, 'worker_count__203': 10, 'census_place_id__203': 52267, 'ind1950__203': 888, 'worker_count__204': 1, 'census_place_id__204': 52267, 'ind1950__204': 716, 'worker_count__205': 3, 'census_place_id__205': 52267, 'ind1950__205': 526, 'worker_count__206': 5, 'census_place_id__206': 52225, 'ind1950__206': 826, 'worker_count__207': 1, 'census_place_id__207': 52225, 'ind1950__207': 699, 'worker_count__208': 5, 'census_place_id__208': 51370, 'ind1950__208': 826, 'worker_count__209': 185, 'census_place_id__209': 51459, 'ind1950__209': 105, 'worker_count__210': 1, 'census_place_id__210': 51459, 'ind1950__210': 488, 'worker_count__211': 1, 'census_place_id__211': 51370, 'ind1950__211': 439, 'worker_count__212': 3, 'census_place_id__212': 51370, 'ind1950__212': 699, 'worker_count__213': 7, 'census_place_id__213': 51945, 'ind1950__213': 669, 'worker_count__214': 1, 'census_place_id__214': 16856, 'ind1950__214': 817}
# 2024-05-15 10:05:48,637 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 10:05:48,638 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ## 1.3

# %%
ipums_etl.copy_worker_count_to_postgres()

# %% [markdown]
# # 2. Create clusters
# Here we build clusters, the central unit of analysis of this project. Clusters are defined build as follows:
# - 2.1 Transform the census data into a population raster covering the entire USA
# - 2.2 Smooth the data with a convolutional kernel
# - 2.3 Cluster nearby high population tiles together using DBSCAN
# - 2.4 Create a cluster-industry table, with the number of people in each cluster working in each industry

# %% [markdown]
# # 3. Create time consistent clusters
# Here we build time consistent clusters, i.e., clusters having a consistent id across time. We do this by:
# - 3.1 Create a table with all clusters in all years
# - 3.2 Intersection matching between clusters in different years
# - 3.3 Create a crosswalk table between cluster ids and time consistent cluster ids
# - 3.4 Create a table with time consistent cluster ids
# - 3.5 Create a table with time consistent cluster ids and industry data
