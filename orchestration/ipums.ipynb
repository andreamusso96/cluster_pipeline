# %%
import ipums_etl as etl
import ipums_time_consistent_cluster as tcc
import config as config

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 1. ETL Data Pipeline
# Here we extract the data from various CSVs, transform it using DuckDB and load the result into a postgres database. We do this in several steps:
# - 1.1 Extract ipums demographic data and the census place project geographic data into a duckdb database.
# - 1.2 Transform the data by: merging the demographic and geographic data into a single table called census. Aggregating the data to the census place industry level (census_place_industry_count table).
# - 1.3 Loading the aggregated data into a postgres database, together with auxiliary data (industry codes, census places)

# %%
etl.extract_data_to_duckdb()
# Out:
# 2024-05-15 12:34:57,374 INFO sqlalchemy.engine.Engine select current_schema()
# 2024-05-15 12:34:57,375 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-05-15 12:34:57,376 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:34:57,380 INFO sqlalchemy.engine.Engine -- Drop tables if they exist for idempotency
# DROP TABLE IF EXISTS "dem_1850";
# DROP TABLE IF EXISTS "geo_1850";
#
# -- Create demographic data table
# CREATE TABLE "dem_1850"
#     (year INTEGER,
#      occ1950 INTEGER,
#      ind1950 INTEGER,
#      histid VARCHAR(36),
#      hik VARCHAR(21));
#
# COPY "dem_1850" FROM '/Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ipums/census/usa_1850.csv';
#
# CREATE INDEX "index_dem_1850_histid" ON "dem_1850" (histid);
#
# WITH duplicates AS (
#     SELECT histid, ROW_NUMBER() OVER(PARTITION BY histid) AS rownum
#     FROM "dem_1850"
#     )
# DELETE FROM "dem_1850" USING duplicates
# WHERE "dem_1850".histid = duplicates.histid AND duplicates.rownum > 1;
#
# -- Create geographic data table
# CREATE TABLE "geo_1850"
#     (potential_match VARCHAR(50),
#      match_type VARCHAR(50),
#      lat FLOAT,
#      lon FLOAT,
#      state_fips_geomatch VARCHAR(2),
#      county_fips_geomatch VARCHAR(5),
#      cluster_k5 INTEGER,
#      cpp_placeid INTEGER,
#      histid VARCHAR(36)
# );
# COPY "geo_1850" FROM '/Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ipums/geo/histid_place_crosswalk_1850.csv';
#
#
# -- Transform histid to uppercase
# CREATE TABLE "geo_1850_new" (census_place_id INTEGER, histid VARCHAR(36));
#
# INSERT INTO "geo_1850_new"
# SELECT cpp_placeid, UPPER(histid) FROM "geo_1850";
#
# DROP TABLE "geo_1850";
# ALTER TABLE "geo_1850_new" RENAME TO "geo_1850";
#
# -- Create index
# CREATE INDEX "index_geo_1850_histid" ON "geo_1850" (histid);
#
# -- Remove duplicates
# WITH duplicates AS (
#     SELECT histid, ROW_NUMBER() OVER(PARTITION BY histid) AS rownum
#     FROM "geo_1850"
#     )
# DELETE FROM "geo_1850" USING duplicates
# WHERE "geo_1850".histid = duplicates.histid AND duplicates.rownum > 1;
# 2024-05-15 12:34:57,380 INFO sqlalchemy.engine.Engine [dialect duckdb+duckdb_engine does not support caching 0.00034s] ()
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 2024-05-15 12:35:17,538 INFO sqlalchemy.engine.Engine COMMIT
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 2024-05-15 12:35:51,622 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:35:51,624 INFO sqlalchemy.engine.Engine -- Drop tables if they exist for idempotency
# DROP TABLE IF EXISTS "dem_1860";
# DROP TABLE IF EXISTS "geo_1860";
#
# -- Create demographic data table
# CREATE TABLE "dem_1860"
#     (year INTEGER,
#      occ1950 INTEGER,
#      ind1950 INTEGER,
#      histid VARCHAR(36),
#      hik VARCHAR(21));
#
# COPY "dem_1860" FROM '/Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ipums/census/usa_1860.csv';
#
# CREATE INDEX "index_dem_1860_histid" ON "dem_1860" (histid);
#
# WITH duplicates AS (
#     SELECT histid, ROW_NUMBER() OVER(PARTITION BY histid) AS rownum
#     FROM "dem_1860"
#     )
# DELETE FROM "dem_1860" USING duplicates
# WHERE "dem_1860".histid = duplicates.histid AND duplicates.rownum > 1;
#
# -- Create geographic data table
# CREATE TABLE "geo_1860"
#     (potential_match VARCHAR(50),
#      match_type VARCHAR(50),
#      lat FLOAT,
#      lon FLOAT,
#      state_fips_geomatch VARCHAR(2),
#      county_fips_geomatch VARCHAR(5),
#      cluster_k5 INTEGER,
#      cpp_placeid INTEGER,
#      histid VARCHAR(36)
# );
# COPY "geo_1860" FROM '/Users/andrea/Desktop/PhD/Data/API/clusterdb/data/ipums/geo/histid_place_crosswalk_1860.csv';
#
#
# -- Transform histid to uppercase
# CREATE TABLE "geo_1860_new" (census_place_id INTEGER, histid VARCHAR(36));
#
# INSERT INTO "geo_1860_new"
# SELECT cpp_placeid, UPPER(histid) FROM "geo_1860";
#
# DROP TABLE "geo_1860";
# ALTER TABLE "geo_1860_new" RENAME TO "geo_1860";
#
# -- Create index
# CREATE INDEX "index_geo_1860_histid" ON "geo_1860" (histid);
#
# -- Remove duplicates
# WITH duplicates AS (
#     SELECT histid, ROW_NUMBER() OVER(PARTITION BY histid) AS rownum
#     FROM "geo_1860"
#     )
# DELETE FROM "geo_1860" USING duplicates
# WHERE "geo_1860".histid = duplicates.histid AND duplicates.rownum > 1;
# 2024-05-15 12:35:51,624 INFO sqlalchemy.engine.Engine [dialect duckdb+duckdb_engine does not support caching 0.00032s] ()
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 2024-05-15 12:36:13,867 INFO sqlalchemy.engine.Engine COMMIT
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
etl.transform_data()
# Out:
# 2024-05-15 12:37:08,866 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:08,868 INFO sqlalchemy.engine.Engine -- Drop tables if they exist for idempotency
# DROP TABLE IF EXISTS "census_1850";
# DROP TABLE IF EXISTS "census_place_industry_count_1850";
#
# -- Create census table
# CREATE TABLE "census_1850"
#     (histid VARCHAR(36),
#      hik VARCHAR(21),
#      ind1950 INTEGER,
#      occ1950 INTEGER,
#      census_place_id INTEGER);
#
# -- Merge the data from the demographic and geographic tables
# INSERT INTO "census_1850"
# SELECT "dem_1850".histid, NULLIF(hik, '                     '), ind1950, occ1950, CASE WHEN census_place_id > 69491 THEN NULL ELSE census_place_id END AS census_place_id
# FROM "dem_1850" LEFT JOIN "geo_1850"
# ON "dem_1850".histid = "geo_1850".histid;
#
# -- Create census place industry count table
# CREATE TABLE "census_place_industry_count_1850" AS
# SELECT census_place_id, ind1950, COUNT(*) AS worker_count
# FROM "census_1850"
# WHERE census_place_id IS NOT NULL
# GROUP BY census_place_id, ind1950;
# 2024-05-15 12:37:08,869 INFO sqlalchemy.engine.Engine [dialect duckdb+duckdb_engine does not support caching 0.00022s] ()
# 2024-05-15 12:37:10,685 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 12:37:10,794 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:10,796 INFO sqlalchemy.engine.Engine -- Drop tables if they exist for idempotency
# DROP TABLE IF EXISTS "census_1860";
# DROP TABLE IF EXISTS "census_place_industry_count_1860";
#
# -- Create census table
# CREATE TABLE "census_1860"
#     (histid VARCHAR(36),
#      hik VARCHAR(21),
#      ind1950 INTEGER,
#      occ1950 INTEGER,
#      census_place_id INTEGER);
#
# -- Merge the data from the demographic and geographic tables
# INSERT INTO "census_1860"
# SELECT "dem_1860".histid, NULLIF(hik, '                     '), ind1950, occ1950, CASE WHEN census_place_id > 69491 THEN NULL ELSE census_place_id END AS census_place_id
# FROM "dem_1860" LEFT JOIN "geo_1860"
# ON "dem_1860".histid = "geo_1860".histid;
#
# -- Create census place industry count table
# CREATE TABLE "census_place_industry_count_1860" AS
# SELECT census_place_id, ind1950, COUNT(*) AS worker_count
# FROM "census_1860"
# WHERE census_place_id IS NOT NULL
# GROUP BY census_place_id, ind1950;
# 2024-05-15 12:37:10,796 INFO sqlalchemy.engine.Engine [dialect duckdb+duckdb_engine does not support caching 0.00022s] ()
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 2024-05-15 12:37:13,273 INFO sqlalchemy.engine.Engine COMMIT

# %%
etl.load_data_to_postgres()
# Out:
# 2024-05-15 12:37:13,688 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2024-05-15 12:37:13,688 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-05-15 12:37:13,689 INFO sqlalchemy.engine.Engine select current_schema()
# 2024-05-15 12:37:13,689 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-05-15 12:37:13,690 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2024-05-15 12:37:13,690 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-05-15 12:37:13,691 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:13,737 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS "census_place" CASCADE;
# DROP TABLE IF EXISTS "industry1950_code" CASCADE;
# DROP TABLE IF EXISTS "usa_geom";
#
# -- Create table for census place data
# CREATE TABLE "census_place" (
#     lat FLOAT,
#     lon FLOAT,
#     consistent_place_3 INTEGER,
#     consistent_place_name_3 VARCHAR(50),
#     consistent_place_5 INTEGER,
#     consistent_place_name_5 VARCHAR(50),
#     consistent_place_10 INTEGER,
#     consistent_place_name_10 VARCHAR(50),
#     consistent_place_50 INTEGER,
#     consistent_place_name_50 VARCHAR(50),
#     consistent_place_100 INTEGER,
#     consistent_place_name_100 VARCHAR(50),
#     consistent_place_200 INTEGER,
#     consistent_place_name_200 VARCHAR(50),
#     consistent_place_300 INTEGER,
#     consistent_place_name_300 VARCHAR(50),
#     consistent_place_500 INTEGER,
#     consistent_place_name_500 VARCHAR(50),
#     fracpop FLOAT,
#     potential_match VARCHAR(50),
#     id INTEGER
# );
#
# COPY "census_place" FROM '/data/ipums/geo/place_component_crosswalk.csv' DELIMITER ',' CSV HEADER;
#
# -- Refactor table to include geometry columns and drop needless columns
# CREATE TABLE "census_place_new"
#     (id INTEGER PRIMARY KEY,
#      potential_match VARCHAR(50),
#      geom GEOGRAPHY
#     );
#
# INSERT INTO "census_place_new"
# SELECT id, potential_match, ST_MakePoint(lon, lat)::GEOGRAPHY AS geom
# FROM "census_place";
#
# DROP TABLE "census_place";
# ALTER TABLE "census_place_new" RENAME TO "census_place";
#
# CREATE INDEX ON "census_place" USING GIST (geom);
#
# -- Create table for industry codes
# CREATE TABLE "industry1950_code" (
#     code INTEGER,
#     description VARCHAR(70),
#     refined_categories VARCHAR(70),
#     broad_categories VARCHAR(70),
#     agri_non_agri VARCHAR(70),
#     detailed VARCHAR(70),
#     no_agriculture VARCHAR(70),
#     all_group_by VARCHAR (70)
# );
#
# COPY "industry1950_code" FROM '/data/ipums/census/industry1950_codes_and_desc.csv' DELIMITER ',' CSV HEADER;
#
# ALTER TABLE "industry1950_code" ADD PRIMARY KEY (code);
#
# -- Create USA geom table
# CREATE TABLE "usa_geom" (
# gid serial,
# "fid" int2,
# "program" varchar(15),
# "state_code" varchar(2),
# "state_name" varchar(20),
# "flowing_st" varchar(1),
# "fid_1" int2,
# geom GEOMETRY(MultiPolygon,4326)
# );
#
# ALTER TABLE "usa_geom" ADD PRIMARY KEY (gid);
#
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('1','PERMIT TRACKING','AL','ALABAMA','F','919','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('2',NULL,'AK','ALASKA','N','920','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('3','AZURITE','AZ','ARIZONA','F','921','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('4','PDS','AR','ARKANSAS','F','922','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('5',NULL,'CA','CALIFORNIA','N','923','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('6','ECOMAP','CO','COLORADO','F','924','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('7','SIMS','CT','CONNECTICUT','F','925','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('8',NULL,'DE','DELAWARE','P','926','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('9',NULL,'DC','DISTRICT OF COLUMBIA','P','927','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('10',NULL,'FL','FLORIDA','P','928','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('11',NULL,'GA','GEORGIA','N','929','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('12','HI-EHW','HI','HAWAII','F','930','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('13',NULL,'ID','IDAHO','P','931','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('14','ACES','IL','ILLINOIS','F','932','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('15','IN-FRS','IN','INDIANA','F','933','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('16','IDNR_EFD','IA','IOWA','F','934','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('17','KS-FP','KS','KANSAS','F','935','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('18','KY-TEMPO','KY','KENTUCKY','F','936','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('19',NULL,'LA','LOUISIANA','P','937','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('20','ME-EFIS','ME','MAINE','F','938','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('21',NULL,'MD','MARYLAND','P','939','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('22','MA-EPICS','MA','MASSACHUSETTS','F','940','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('23',NULL,'MI','MICHIGAN','P','941','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('24','MN-DELTA','MN','MINNESOTA','F','942','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('25','MS-ENSITE','MS','MISSISSIPPI','F','943','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('26','MO-DNR','MO','MISSOURI','F','944','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('27','MT-CEDARS','MT','MONTANA','F','945','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('28','NDEQ','NE','NEBRASKA','F','946','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('29','NV-FP','NV','NEVADA','F','947','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('30','NH-DES','NH','NEW HAMPSHIRE','F','948','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('31','NJ-NJEMS','NJ','NEW JERSEY','F','949','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('32',NULL,'NM','NEW MEXICO','P','950','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('33','FIS','NY','NEW YORK','F','951','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('34',NULL,'NC','NORTH CAROLINA','N','952','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('35',NULL,'ND','NORTH DAKOTA','N','953','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('36',NULL,'OH','OHIO','P','954','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('37','OK-FMS','OK','OKLAHOMA','F','955','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('38',NULL,'OR','OREGON','N','956','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('39','PA-EFACTS','PA','PENNSYLVANIA','F','957','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('40',NULL,'RI','RHODE ISLAND','N','958','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('41',NULL,'SC','SOUTH CAROLINA','N','959','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('42',NULL,'SD','SOUTH DAKOTA','P','960','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('43',NULL,'TN','TENNESSEE','P','961','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('44','TX-TCEQ ACR','TX','TEXAS','F','962','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('45',NULL,'UT','UTAH','N','963','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('46',NULL,'VT','VERMONT','P','964','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('47',NULL,'VA','VIRGINIA','P','965','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('48','WA-FSIS','WA','WASHINGTON','F','966','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('49',NULL,'WV','WEST VIRGINIA','N','967','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('50','WI-ESR','WI','WISCONSIN','F','968','...');
# INSERT INTO "usa_geom" ("fid","program","state_code","state_name","flowing_st","fid_1",geom) VALUES ('51',NULL,'WY','WYOMING','N','969','...');
#
# CREATE TABLE "usa_geom_new"
#     (state_code VARCHAR(2) PRIMARY KEY,
#      state_name VARCHAR(25),
#      geom GEOMETRY);
#
# INSERT INTO "usa_geom_new"
# SELECT state_code, state_name, geom
# FROM "usa_geom";
#
# DROP TABLE "usa_geom";
# ALTER TABLE "usa_geom_new" RENAME TO "usa_geom";
# 2024-05-15 12:37:13,739 INFO sqlalchemy.engine.Engine [generated in 0.00151s] {}
# 2024-05-15 12:37:14,145 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 12:37:14,150 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:14,150 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS census_place_industry_count_1850
# 2024-05-15 12:37:14,151 INFO sqlalchemy.engine.Engine [generated in 0.00061s] {}
# 2024-05-15 12:37:14,152 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 12:37:14,154 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:14,154 INFO sqlalchemy.engine.Engine SELECT * FROM census_place_industry_count_1850
# 2024-05-15 12:37:14,154 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-05-15 12:37:14,162 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:14,165 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-05-15 12:37:14,165 INFO sqlalchemy.engine.Engine [generated in 0.00041s] {'table_name': 'census_place_industry_count_1850', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-05-15 12:37:14,166 INFO sqlalchemy.engine.Engine
# CREATE TABLE census_place_industry_count_1850 (
# 	census_place_id BIGINT,
# 	ind1950 BIGINT,
# 	worker_count BIGINT
# )
#
#
# 2024-05-15 12:37:14,167 INFO sqlalchemy.engine.Engine [no key 0.00021s] {}
# 2024-05-15 12:37:14,181 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 12:37:14,182 INFO sqlalchemy.engine.Engine [generated in 0.00979s (insertmanyvalues) 1/10 (unordered)] {'census_place_id__0': 28533, 'worker_count__0': 1148, 'ind1950__0': 246, 'census_place_id__1': 28533, 'worker_count__1': 95, 'ind1950__1': 679, 'census_place_id__2': 28533, 'worker_count__2': 110, 'ind1950__2': 309, 'census_place_id__3': 28533, 'worker_count__3': 192, 'ind1950__3': 808, 'census_place_id__4': 28533, 'worker_count__4': 8, 'ind1950__4': 429, 'census_place_id__5': 28533, 'worker_count__5': 8, 'ind1950__5': 657, 'census_place_id__6': 28533, 'worker_count__6': 73, 'ind1950__6': 888, 'census_place_id__7': 28533, 'worker_count__7': 367, 'ind1950__7': 817, 'census_place_id__8': 28533, 'worker_count__8': 14, 'ind1950__8': 388, 'census_place_id__9': 28533, 'worker_count__9': 25, 'ind1950__9': 646, 'census_place_id__10': 28533, 'worker_count__10': 14, 'ind1950__10': 716, 'census_place_id__11': 28533, 'worker_count__11': 59, 'ind1950__11': 526, 'census_place_id__12': 28533, 'worker_count__12': 18, 'ind1950__12': 448, 'census_place_id__13': 28533, 'worker_count__13': 8, 'ind1950__13': 579, 'census_place_id__14': 28533, 'worker_count__14': 39, 'ind1950__14': 378, 'census_place_id__15': 28533, 'worker_count__15': 21, 'ind1950__15': 337, 'census_place_id__16': 28533, 'worker_count__16': 15 ... 2900 parameters truncated ... 'worker_count__983': 7, 'ind1950__983': 868, 'census_place_id__984': 42328, 'worker_count__984': 1, 'ind1950__984': 326, 'census_place_id__985': 42676, 'worker_count__985': 12, 'ind1950__985': 699, 'census_place_id__986': 42191, 'worker_count__986': 8, 'ind1950__986': 409, 'census_place_id__987': 43404, 'worker_count__987': 563, 'ind1950__987': 105, 'census_place_id__988': 43404, 'worker_count__988': 21, 'ind1950__988': 488, 'census_place_id__989': 43404, 'worker_count__989': 16, 'ind1950__989': 499, 'census_place_id__990': 42191, 'worker_count__990': 1, 'ind1950__990': 868, 'census_place_id__991': 43404, 'worker_count__991': 1, 'ind1950__991': 906, 'census_place_id__992': 41684, 'worker_count__992': 17, 'ind1950__992': 216, 'census_place_id__993': 41684, 'worker_count__993': 12, 'ind1950__993': 699, 'census_place_id__994': 41684, 'worker_count__994': 1, 'ind1950__994': 439, 'census_place_id__995': 41684, 'worker_count__995': 2, 'ind1950__995': 568, 'census_place_id__996': 42910, 'worker_count__996': 10, 'ind1950__996': 656, 'census_place_id__997': 42910, 'worker_count__997': 1, 'ind1950__997': 879, 'census_place_id__998': 41798, 'worker_count__998': 3, 'ind1950__998': 699, 'census_place_id__999': 40621, 'worker_count__999': 179, 'ind1950__999': 105}
# 2024-05-15 12:37:14,189 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 12:37:14,189 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/10 (unordered)] {'census_place_id__0': 40621, 'worker_count__0': 8, 'ind1950__0': 488, 'census_place_id__1': 40621, 'worker_count__1': 1, 'ind1950__1': 499, 'census_place_id__2': 39652, 'worker_count__2': 2939, 'ind1950__2': 0, 'census_place_id__3': 39652, 'worker_count__3': 13, 'ind1950__3': 636, 'census_place_id__4': 39652, 'worker_count__4': 4, 'ind1950__4': 358, 'census_place_id__5': 39652, 'worker_count__5': 2, 'ind1950__5': 306, 'census_place_id__6': 39652, 'worker_count__6': 10, 'ind1950__6': 307, 'census_place_id__7': 39652, 'worker_count__7': 1, 'ind1950__7': 459, 'census_place_id__8': 39652, 'worker_count__8': 1, 'ind1950__8': 317, 'census_place_id__9': 40217, 'worker_count__9': 1276, 'ind1950__9': 0, 'census_place_id__10': 40217, 'worker_count__10': 1, 'ind1950__10': 636, 'census_place_id__11': 40217, 'worker_count__11': 1, 'ind1950__11': 307, 'census_place_id__12': 40138, 'worker_count__12': 2, 'ind1950__12': 896, 'census_place_id__13': 40138, 'worker_count__13': 2, 'ind1950__13': 399, 'census_place_id__14': 40739, 'worker_count__14': 2, 'ind1950__14': 946, 'census_place_id__15': 40739, 'worker_count__15': 4, 'ind1950__15': 896, 'census_place_id__16': 40739, 'worker_count__16': 7 ... 2900 parameters truncated ... 'worker_count__983': 2, 'ind1950__983': 868, 'census_place_id__984': 37903, 'worker_count__984': 3, 'ind1950__984': 409, 'census_place_id__985': 37152, 'worker_count__985': 2, 'ind1950__985': 888, 'census_place_id__986': 37152, 'worker_count__986': 12, 'ind1950__986': 246, 'census_place_id__987': 37152, 'worker_count__987': 5, 'ind1950__987': 817, 'census_place_id__988': 37152, 'worker_count__988': 1, 'ind1950__988': 526, 'census_place_id__989': 35907, 'worker_count__989': 3, 'ind1950__989': 868, 'census_place_id__990': 35907, 'worker_count__990': 4, 'ind1950__990': 379, 'census_place_id__991': 34932, 'worker_count__991': 16, 'ind1950__991': 308, 'census_place_id__992': 34932, 'worker_count__992': 3, 'ind1950__992': 487, 'census_place_id__993': 34932, 'worker_count__993': 3, 'ind1950__993': 489, 'census_place_id__994': 34932, 'worker_count__994': 3, 'ind1950__994': 546, 'census_place_id__995': 34876, 'worker_count__995': 268, 'ind1950__995': 0, 'census_place_id__996': 34876, 'worker_count__996': 1, 'ind1950__996': 358, 'census_place_id__997': 34876, 'worker_count__997': 2, 'ind1950__997': 636, 'census_place_id__998': 35102, 'worker_count__998': 12, 'ind1950__998': 656, 'census_place_id__999': 34876, 'worker_count__999': 1, 'ind1950__999': 306}
# 2024-05-15 12:37:14,196 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 12:37:14,196 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/10 (unordered)] {'census_place_id__0': 34876, 'worker_count__0': 1, 'ind1950__0': 936, 'census_place_id__1': 35310, 'worker_count__1': 1, 'ind1950__1': 879, 'census_place_id__2': 35310, 'worker_count__2': 2, 'ind1950__2': 656, 'census_place_id__3': 35470, 'worker_count__3': 2, 'ind1950__3': 879, 'census_place_id__4': 35470, 'worker_count__4': 6, 'ind1950__4': 656, 'census_place_id__5': 35177, 'worker_count__5': 340, 'ind1950__5': 105, 'census_place_id__6': 35177, 'worker_count__6': 5, 'ind1950__6': 488, 'census_place_id__7': 35927, 'worker_count__7': 3, 'ind1950__7': 308, 'census_place_id__8': 35927, 'worker_count__8': 3, 'ind1950__8': 637, 'census_place_id__9': 35927, 'worker_count__9': 3, 'ind1950__9': 489, 'census_place_id__10': 35927, 'worker_count__10': 1, 'ind1950__10': 546, 'census_place_id__11': 36353, 'worker_count__11': 155, 'ind1950__11': 105, 'census_place_id__12': 36353, 'worker_count__12': 4, 'ind1950__12': 488, 'census_place_id__13': 36173, 'worker_count__13': 1134, 'ind1950__13': 0, 'census_place_id__14': 36173, 'worker_count__14': 2, 'ind1950__14': 636, 'census_place_id__15': 36173, 'worker_count__15': 3, 'ind1950__15': 306, 'census_place_id__16': 36173, 'worker_count__16': 2 ... 2900 parameters truncated ... 'worker_count__983': 3, 'ind1950__983': 868, 'census_place_id__984': 34386, 'worker_count__984': 26, 'ind1950__984': 817, 'census_place_id__985': 34386, 'worker_count__985': 5, 'ind1950__985': 888, 'census_place_id__986': 34386, 'worker_count__986': 1, 'ind1950__986': 448, 'census_place_id__987': 34386, 'worker_count__987': 4, 'ind1950__987': 378, 'census_place_id__988': 34386, 'worker_count__988': 4, 'ind1950__988': 309, 'census_place_id__989': 34386, 'worker_count__989': 54, 'ind1950__989': 246, 'census_place_id__990': 34386, 'worker_count__990': 19, 'ind1950__990': 337, 'census_place_id__991': 34386, 'worker_count__991': 1, 'ind1950__991': 526, 'census_place_id__992': 34386, 'worker_count__992': 1, 'ind1950__992': 898, 'census_place_id__993': 34386, 'worker_count__993': 2, 'ind1950__993': 679, 'census_place_id__994': 34386, 'worker_count__994': 3, 'ind1950__994': 388, 'census_place_id__995': 34916, 'worker_count__995': 82, 'ind1950__995': 488, 'census_place_id__996': 34916, 'worker_count__996': 233, 'ind1950__996': 105, 'census_place_id__997': 34916, 'worker_count__997': 1, 'ind1950__997': 436, 'census_place_id__998': 34916, 'worker_count__998': 1, 'ind1950__998': 899, 'census_place_id__999': 34916, 'worker_count__999': 7, 'ind1950__999': 416}
# 2024-05-15 12:37:14,202 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 12:37:14,202 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/10 (unordered)] {'census_place_id__0': 34916, 'worker_count__0': 8, 'ind1950__0': 499, 'census_place_id__1': 34916, 'worker_count__1': 2, 'ind1950__1': 697, 'census_place_id__2': 34916, 'worker_count__2': 1, 'ind1950__2': 316, 'census_place_id__3': 34304, 'worker_count__3': 29, 'ind1950__3': 488, 'census_place_id__4': 34304, 'worker_count__4': 316, 'ind1950__4': 105, 'census_place_id__5': 34304, 'worker_count__5': 1, 'ind1950__5': 697, 'census_place_id__6': 34304, 'worker_count__6': 28, 'ind1950__6': 316, 'census_place_id__7': 34304, 'worker_count__7': 1, 'ind1950__7': 416, 'census_place_id__8': 34304, 'worker_count__8': 1, 'ind1950__8': 499, 'census_place_id__9': 34002, 'worker_count__9': 3, 'ind1950__9': 546, 'census_place_id__10': 34002, 'worker_count__10': 1, 'ind1950__10': 308, 'census_place_id__11': 34002, 'worker_count__11': 1, 'ind1950__11': 487, 'census_place_id__12': 34002, 'worker_count__12': 2, 'ind1950__12': 489, 'census_place_id__13': 32900, 'worker_count__13': 23, 'ind1950__13': 546, 'census_place_id__14': 34471, 'worker_count__14': 342, 'ind1950__14': 246, 'census_place_id__15': 34471, 'worker_count__15': 7, 'ind1950__15': 808, 'census_place_id__16': 34471, 'worker_count__16': 39 ... 2900 parameters truncated ... 'worker_count__983': 24, 'ind1950__983': 488, 'census_place_id__984': 36998, 'worker_count__984': 1, 'ind1950__984': 326, 'census_place_id__985': 35828, 'worker_count__985': 1, 'ind1950__985': 499, 'census_place_id__986': 36688, 'worker_count__986': 7, 'ind1950__986': 439, 'census_place_id__987': 36688, 'worker_count__987': 2, 'ind1950__987': 699, 'census_place_id__988': 35828, 'worker_count__988': 1, 'ind1950__988': 906, 'census_place_id__989': 36688, 'worker_count__989': 1, 'ind1950__989': 318, 'census_place_id__990': 36462, 'worker_count__990': 25, 'ind1950__990': 488, 'census_place_id__991': 36462, 'worker_count__991': 273, 'ind1950__991': 105, 'census_place_id__992': 36462, 'worker_count__992': 2, 'ind1950__992': 416, 'census_place_id__993': 36462, 'worker_count__993': 2, 'ind1950__993': 436, 'census_place_id__994': 36462, 'worker_count__994': 1, 'ind1950__994': 906, 'census_place_id__995': 36561, 'worker_count__995': 1376, 'ind1950__995': 0, 'census_place_id__996': 36561, 'worker_count__996': 3, 'ind1950__996': 459, 'census_place_id__997': 36561, 'worker_count__997': 1, 'ind1950__997': 306, 'census_place_id__998': 36561, 'worker_count__998': 1, 'ind1950__998': 338, 'census_place_id__999': 36561, 'worker_count__999': 7, 'ind1950__999': 836}
# 2024-05-15 12:37:14,209 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 12:37:14,209 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/10 (unordered)] {'census_place_id__0': 36561, 'worker_count__0': 8, 'ind1950__0': 636, 'census_place_id__1': 36561, 'worker_count__1': 8, 'ind1950__1': 358, 'census_place_id__2': 36561, 'worker_count__2': 2, 'ind1950__2': 687, 'census_place_id__3': 36561, 'worker_count__3': 1, 'ind1950__3': 936, 'census_place_id__4': 36561, 'worker_count__4': 1, 'ind1950__4': 418, 'census_place_id__5': 35762, 'worker_count__5': 3, 'ind1950__5': 346, 'census_place_id__6': 35762, 'worker_count__6': 1, 'ind1950__6': 896, 'census_place_id__7': 36943, 'worker_count__7': 10, 'ind1950__7': 409, 'census_place_id__8': 36943, 'worker_count__8': 4, 'ind1950__8': 868, 'census_place_id__9': 36943, 'worker_count__9': 1, 'ind1950__9': 326, 'census_place_id__10': 36943, 'worker_count__10': 1, 'ind1950__10': 859, 'census_place_id__11': 36908, 'worker_count__11': 8, 'ind1950__11': 439, 'census_place_id__12': 36908, 'worker_count__12': 4, 'ind1950__12': 699, 'census_place_id__13': 36908, 'worker_count__13': 2, 'ind1950__13': 216, 'census_place_id__14': 40324, 'worker_count__14': 1, 'ind1950__14': 358, 'census_place_id__15': 41572, 'worker_count__15': 1, 'ind1950__15': 888, 'census_place_id__16': 44654, 'worker_count__16': 1 ... 2900 parameters truncated ... 'worker_count__983': 2, 'ind1950__983': 836, 'census_place_id__984': 17434, 'worker_count__984': 4, 'ind1950__984': 307, 'census_place_id__985': 13920, 'worker_count__985': 148, 'ind1950__985': 546, 'census_place_id__986': 13920, 'worker_count__986': 72, 'ind1950__986': 308, 'census_place_id__987': 13920, 'worker_count__987': 2, 'ind1950__987': 347, 'census_place_id__988': 13920, 'worker_count__988': 7, 'ind1950__988': 489, 'census_place_id__989': 13920, 'worker_count__989': 6, 'ind1950__989': 849, 'census_place_id__990': 13920, 'worker_count__990': 1, 'ind1950__990': 916, 'census_place_id__991': 13709, 'worker_count__991': 24, 'ind1950__991': 896, 'census_place_id__992': 13709, 'worker_count__992': 8, 'ind1950__992': 346, 'census_place_id__993': 13709, 'worker_count__993': 1, 'ind1950__993': 858, 'census_place_id__994': 13709, 'worker_count__994': 6, 'ind1950__994': 516, 'census_place_id__995': 13709, 'worker_count__995': 6, 'ind1950__995': 399, 'census_place_id__996': 13709, 'worker_count__996': 2, 'ind1950__996': 946, 'census_place_id__997': 19143, 'worker_count__997': 2, 'ind1950__997': 868, 'census_place_id__998': 18462, 'worker_count__998': 42, 'ind1950__998': 546, 'census_place_id__999': 18709, 'worker_count__999': 430, 'ind1950__999': 0}
# 2024-05-15 12:37:14,216 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 12:37:14,217 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/10 (unordered)] {'census_place_id__0': 46730, 'worker_count__0': 1, 'ind1950__0': 216, 'census_place_id__1': 15991, 'worker_count__1': 1, 'ind1950__1': 526, 'census_place_id__2': 18272, 'worker_count__2': 3, 'ind1950__2': 896, 'census_place_id__3': 17821, 'worker_count__3': 36, 'ind1950__3': 105, 'census_place_id__4': 18462, 'worker_count__4': 1, 'ind1950__4': 916, 'census_place_id__5': 16755, 'worker_count__5': 18, 'ind1950__5': 105, 'census_place_id__6': 16755, 'worker_count__6': 1, 'ind1950__6': 488, 'census_place_id__7': 16810, 'worker_count__7': 2, 'ind1950__7': 379, 'census_place_id__8': 16810, 'worker_count__8': 14, 'ind1950__8': 868, 'census_place_id__9': 16810, 'worker_count__9': 4, 'ind1950__9': 409, 'census_place_id__10': 17532, 'worker_count__10': 12, 'ind1950__10': 105, 'census_place_id__11': 17532, 'worker_count__11': 15, 'ind1950__11': 488, 'census_place_id__12': 17532, 'worker_count__12': 3, 'ind1950__12': 416, 'census_place_id__13': 17532, 'worker_count__13': 2, 'ind1950__13': 499, 'census_place_id__14': 17532, 'worker_count__14': 1, 'ind1950__14': 608, 'census_place_id__15': 17532, 'worker_count__15': 1, 'ind1950__15': 899, 'census_place_id__16': 17692, 'worker_count__16': 5 ... 2900 parameters truncated ... 'worker_count__983': 1, 'ind1950__983': 308, 'census_place_id__984': 42902, 'worker_count__984': 1, 'ind1950__984': 489, 'census_place_id__985': 42909, 'worker_count__985': 1, 'ind1950__985': 526, 'census_place_id__986': 42753, 'worker_count__986': 1, 'ind1950__986': 868, 'census_place_id__987': 37402, 'worker_count__987': 7, 'ind1950__987': 699, 'census_place_id__988': 38551, 'worker_count__988': 872, 'ind1950__988': 0, 'census_place_id__989': 42753, 'worker_count__989': 1, 'ind1950__989': 409, 'census_place_id__990': 38752, 'worker_count__990': 6, 'ind1950__990': 656, 'census_place_id__991': 38752, 'worker_count__991': 1, 'ind1950__991': 669, 'census_place_id__992': 42509, 'worker_count__992': 1, 'ind1950__992': 399, 'census_place_id__993': 38428, 'worker_count__993': 1, 'ind1950__993': 896, 'census_place_id__994': 38435, 'worker_count__994': 1118, 'ind1950__994': 0, 'census_place_id__995': 38786, 'worker_count__995': 8, 'ind1950__995': 488, 'census_place_id__996': 38435, 'worker_count__996': 3, 'ind1950__996': 358, 'census_place_id__997': 38786, 'worker_count__997': 188, 'ind1950__997': 105, 'census_place_id__998': 38786, 'worker_count__998': 2, 'ind1950__998': 499, 'census_place_id__999': 38984, 'worker_count__999': 4, 'ind1950__999': 546}
# 2024-05-15 12:37:14,224 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 12:37:14,224 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/10 (unordered)] {'census_place_id__0': 38984, 'worker_count__0': 3, 'ind1950__0': 308, 'census_place_id__1': 38984, 'worker_count__1': 2, 'ind1950__1': 489, 'census_place_id__2': 38984, 'worker_count__2': 2, 'ind1950__2': 487, 'census_place_id__3': 38875, 'worker_count__3': 350, 'ind1950__3': 0, 'census_place_id__4': 38875, 'worker_count__4': 4, 'ind1950__4': 636, 'census_place_id__5': 38875, 'worker_count__5': 2, 'ind1950__5': 696, 'census_place_id__6': 38875, 'worker_count__6': 2, 'ind1950__6': 459, 'census_place_id__7': 39214, 'worker_count__7': 3, 'ind1950__7': 409, 'census_place_id__8': 39214, 'worker_count__8': 1, 'ind1950__8': 379, 'census_place_id__9': 39457, 'worker_count__9': 4, 'ind1950__9': 379, 'census_place_id__10': 39457, 'worker_count__10': 7, 'ind1950__10': 409, 'census_place_id__11': 39235, 'worker_count__11': 16, 'ind1950__11': 246, 'census_place_id__12': 39235, 'worker_count__12': 2, 'ind1950__12': 679, 'census_place_id__13': 39235, 'worker_count__13': 8, 'ind1950__13': 817, 'census_place_id__14': 39214, 'worker_count__14': 1, 'ind1950__14': 326, 'census_place_id__15': 39457, 'worker_count__15': 1, 'ind1950__15': 868, 'census_place_id__16': 39235, 'worker_count__16': 1 ... 2900 parameters truncated ... 'worker_count__983': 21, 'ind1950__983': 246, 'census_place_id__984': 48285, 'worker_count__984': 14, 'ind1950__984': 817, 'census_place_id__985': 48285, 'worker_count__985': 2, 'ind1950__985': 526, 'census_place_id__986': 45015, 'worker_count__986': 7383, 'ind1950__986': 0, 'census_place_id__987': 45015, 'worker_count__987': 2, 'ind1950__987': 936, 'census_place_id__988': 45015, 'worker_count__988': 152, 'ind1950__988': 358, 'census_place_id__989': 45015, 'worker_count__989': 11, 'ind1950__989': 459, 'census_place_id__990': 45015, 'worker_count__990': 15, 'ind1950__990': 636, 'census_place_id__991': 45015, 'worker_count__991': 5, 'ind1950__991': 536, 'census_place_id__992': 45015, 'worker_count__992': 1, 'ind1950__992': 418, 'census_place_id__993': 45093, 'worker_count__993': 6, 'ind1950__993': 868, 'census_place_id__994': 45093, 'worker_count__994': 3, 'ind1950__994': 409, 'census_place_id__995': 47396, 'worker_count__995': 6, 'ind1950__995': 489, 'census_place_id__996': 47396, 'worker_count__996': 20, 'ind1950__996': 546, 'census_place_id__997': 47396, 'worker_count__997': 1, 'ind1950__997': 347, 'census_place_id__998': 47396, 'worker_count__998': 5, 'ind1950__998': 308, 'census_place_id__999': 47301, 'worker_count__999': 14, 'ind1950__999': 699}
# 2024-05-15 12:37:14,231 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 12:37:14,231 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/10 (unordered)] {'census_place_id__0': 45861, 'worker_count__0': 4, 'ind1950__0': 879, 'census_place_id__1': 45861, 'worker_count__1': 2, 'ind1950__1': 656, 'census_place_id__2': 45160, 'worker_count__2': 14, 'ind1950__2': 699, 'census_place_id__3': 45160, 'worker_count__3': 2, 'ind1950__3': 568, 'census_place_id__4': 45160, 'worker_count__4': 2, 'ind1950__4': 439, 'census_place_id__5': 45798, 'worker_count__5': 5, 'ind1950__5': 379, 'census_place_id__6': 45798, 'worker_count__6': 2, 'ind1950__6': 868, 'census_place_id__7': 45798, 'worker_count__7': 8, 'ind1950__7': 409, 'census_place_id__8': 45429, 'worker_count__8': 10, 'ind1950__8': 699, 'census_place_id__9': 45429, 'worker_count__9': 5, 'ind1950__9': 216, 'census_place_id__10': 45429, 'worker_count__10': 1, 'ind1950__10': 627, 'census_place_id__11': 45429, 'worker_count__11': 1, 'ind1950__11': 568, 'census_place_id__12': 47174, 'worker_count__12': 23, 'ind1950__12': 699, 'census_place_id__13': 45429, 'worker_count__13': 1, 'ind1950__13': 826, 'census_place_id__14': 47027, 'worker_count__14': 25, 'ind1950__14': 246, 'census_place_id__15': 47027, 'worker_count__15': 9, 'ind1950__15': 817, 'census_place_id__16': 47027, 'worker_count__16': 1 ... 2900 parameters truncated ... 'worker_count__983': 1, 'ind1950__983': 489, 'census_place_id__984': 36542, 'worker_count__984': 1, 'ind1950__984': 439, 'census_place_id__985': 7536, 'worker_count__985': 2029, 'ind1950__985': 105, 'census_place_id__986': 7536, 'worker_count__986': 3, 'ind1950__986': 416, 'census_place_id__987': 7536, 'worker_count__987': 11, 'ind1950__987': 488, 'census_place_id__988': 7536, 'worker_count__988': 1, 'ind1950__988': 499, 'census_place_id__989': 7536, 'worker_count__989': 2, 'ind1950__989': 906, 'census_place_id__990': 5486, 'worker_count__990': 2, 'ind1950__990': 656, 'census_place_id__991': 5486, 'worker_count__991': 5, 'ind1950__991': 879, 'census_place_id__992': 5486, 'worker_count__992': 1, 'ind1950__992': 669, 'census_place_id__993': 5486, 'worker_count__993': 1, 'ind1950__993': 126, 'census_place_id__994': 6622, 'worker_count__994': 1424, 'ind1950__994': 0, 'census_place_id__995': 6622, 'worker_count__995': 1, 'ind1950__995': 358, 'census_place_id__996': 6622, 'worker_count__996': 1, 'ind1950__996': 836, 'census_place_id__997': 5585, 'worker_count__997': 12, 'ind1950__997': 879, 'census_place_id__998': 5585, 'worker_count__998': 6, 'ind1950__998': 656, 'census_place_id__999': 6070, 'worker_count__999': 336, 'ind1950__999': 105}
# 2024-05-15 12:37:14,237 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 12:37:14,237 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/10 (unordered)] {'census_place_id__0': 6292, 'worker_count__0': 35, 'ind1950__0': 726, 'census_place_id__1': 6292, 'worker_count__1': 112, 'ind1950__1': 868, 'census_place_id__2': 6292, 'worker_count__2': 22, 'ind1950__2': 326, 'census_place_id__3': 6292, 'worker_count__3': 17, 'ind1950__3': 859, 'census_place_id__4': 6292, 'worker_count__4': 19, 'ind1950__4': 379, 'census_place_id__5': 6292, 'worker_count__5': 2, 'ind1950__5': 587, 'census_place_id__6': 6292, 'worker_count__6': 2, 'ind1950__6': 897, 'census_place_id__7': 6292, 'worker_count__7': 3, 'ind1950__7': 619, 'census_place_id__8': 6292, 'worker_count__8': 4, 'ind1950__8': 506, 'census_place_id__9': 6292, 'worker_count__9': 7, 'ind1950__9': 409, 'census_place_id__10': 6292, 'worker_count__10': 2, 'ind1950__10': 869, 'census_place_id__11': 6395, 'worker_count__11': 47, 'ind1950__11': 526, 'census_place_id__12': 6395, 'worker_count__12': 197, 'ind1950__12': 246, 'census_place_id__13': 6395, 'worker_count__13': 60, 'ind1950__13': 817, 'census_place_id__14': 6395, 'worker_count__14': 16, 'ind1950__14': 378, 'census_place_id__15': 6395, 'worker_count__15': 7, 'ind1950__15': 888, 'census_place_id__16': 6395, 'worker_count__16': 9 ... 2900 parameters truncated ... 'worker_count__983': 3, 'ind1950__983': 336, 'census_place_id__984': 52765, 'worker_count__984': 1, 'ind1950__984': 378, 'census_place_id__985': 52765, 'worker_count__985': 4, 'ind1950__985': 888, 'census_place_id__986': 52765, 'worker_count__986': 22, 'ind1950__986': 246, 'census_place_id__987': 52765, 'worker_count__987': 3, 'ind1950__987': 336, 'census_place_id__988': 52765, 'worker_count__988': 10, 'ind1950__988': 817, 'census_place_id__989': 52765, 'worker_count__989': 2, 'ind1950__989': 808, 'census_place_id__990': 52765, 'worker_count__990': 2, 'ind1950__990': 309, 'census_place_id__991': 53149, 'worker_count__991': 2471, 'ind1950__991': 0, 'census_place_id__992': 53149, 'worker_count__992': 1, 'ind1950__992': 636, 'census_place_id__993': 53149, 'worker_count__993': 1, 'ind1950__993': 358, 'census_place_id__994': 53149, 'worker_count__994': 2, 'ind1950__994': 836, 'census_place_id__995': 53149, 'worker_count__995': 2, 'ind1950__995': 936, 'census_place_id__996': 53149, 'worker_count__996': 3, 'ind1950__996': 306, 'census_place_id__997': 53295, 'worker_count__997': 5, 'ind1950__997': 379, 'census_place_id__998': 53295, 'worker_count__998': 5, 'ind1950__998': 868, 'census_place_id__999': 53295, 'worker_count__999': 3, 'ind1950__999': 409}
# 2024-05-15 12:37:14,244 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 12:37:14,244 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/10 (unordered)] {'census_place_id__0': 53784, 'worker_count__0': 622, 'ind1950__0': 105, 'census_place_id__1': 53784, 'worker_count__1': 112, 'ind1950__1': 488, 'census_place_id__2': 53784, 'worker_count__2': 25, 'ind1950__2': 499, 'census_place_id__3': 53784, 'worker_count__3': 12, 'ind1950__3': 416, 'census_place_id__4': 53070, 'worker_count__4': 1884, 'ind1950__4': 0, 'census_place_id__5': 53070, 'worker_count__5': 5, 'ind1950__5': 636, 'census_place_id__6': 53070, 'worker_count__6': 5, 'ind1950__6': 307, 'census_place_id__7': 53070, 'worker_count__7': 1, 'ind1950__7': 306, 'census_place_id__8': 53070, 'worker_count__8': 4, 'ind1950__8': 836, 'census_place_id__9': 52928, 'worker_count__9': 2, 'ind1950__9': 346, 'census_place_id__10': 52928, 'worker_count__10': 1, 'ind1950__10': 516, 'census_place_id__11': 53302, 'worker_count__11': 10, 'ind1950__11': 868, 'census_place_id__12': 53302, 'worker_count__12': 16, 'ind1950__12': 409, 'census_place_id__13': 53302, 'worker_count__13': 7, 'ind1950__13': 379, 'census_place_id__14': 53302, 'worker_count__14': 10, 'ind1950__14': 326, 'census_place_id__15': 53302, 'worker_count__15': 1, 'ind1950__15': 506, 'census_place_id__16': 53386, 'worker_count__16': 2092 ... 2900 parameters truncated ... 'worker_count__983': 10, 'ind1950__983': 489, 'census_place_id__984': 38791, 'worker_count__984': 2, 'ind1950__984': 487, 'census_place_id__985': 38791, 'worker_count__985': 1, 'ind1950__985': 849, 'census_place_id__986': 37237, 'worker_count__986': 1, 'ind1950__986': 879, 'census_place_id__987': 37602, 'worker_count__987': 1, 'ind1950__987': 399, 'census_place_id__988': 37602, 'worker_count__988': 2, 'ind1950__988': 896, 'census_place_id__989': 37602, 'worker_count__989': 2, 'ind1950__989': 346, 'census_place_id__990': 36984, 'worker_count__990': 7, 'ind1950__990': 246, 'census_place_id__991': 36984, 'worker_count__991': 1, 'ind1950__991': 817, 'census_place_id__992': 36984, 'worker_count__992': 1, 'ind1950__992': 309, 'census_place_id__993': 39601, 'worker_count__993': 3, 'ind1950__993': 308, 'census_place_id__994': 39465, 'worker_count__994': 7, 'ind1950__994': 308, 'census_place_id__995': 39465, 'worker_count__995': 2, 'ind1950__995': 489, 'census_place_id__996': 39338, 'worker_count__996': 8, 'ind1950__996': 817, 'census_place_id__997': 39338, 'worker_count__997': 16, 'ind1950__997': 246, 'census_place_id__998': 39338, 'worker_count__998': 1, 'ind1950__998': 888, 'census_place_id__999': 39817, 'worker_count__999': 1, 'ind1950__999': 669}
# 2024-05-15 12:37:14,250 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 12:37:14,259 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:14,259 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-05-15 12:37:14,260 INFO sqlalchemy.engine.Engine [cached since 0.09503s ago] {'table_name': 'census_place_industry_count_1850', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-05-15 12:37:14,305 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 12:37:14,305 INFO sqlalchemy.engine.Engine [generated in 0.03992s (insertmanyvalues) 1/10 (unordered)] {'census_place_id__0': 39817, 'worker_count__0': 5, 'ind1950__0': 656, 'census_place_id__1': 39817, 'worker_count__1': 1, 'ind1950__1': 879, 'census_place_id__2': 38946, 'worker_count__2': 374, 'ind1950__2': 0, 'census_place_id__3': 38957, 'worker_count__3': 7, 'ind1950__3': 246, 'census_place_id__4': 38957, 'worker_count__4': 2, 'ind1950__4': 817, 'census_place_id__5': 38953, 'worker_count__5': 9, 'ind1950__5': 308, 'census_place_id__6': 38415, 'worker_count__6': 3, 'ind1950__6': 409, 'census_place_id__7': 38415, 'worker_count__7': 3, 'ind1950__7': 868, 'census_place_id__8': 38350, 'worker_count__8': 6, 'ind1950__8': 308, 'census_place_id__9': 38361, 'worker_count__9': 6, 'ind1950__9': 488, 'census_place_id__10': 38361, 'worker_count__10': 190, 'ind1950__10': 105, 'census_place_id__11': 38377, 'worker_count__11': 1, 'ind1950__11': 656, 'census_place_id__12': 37995, 'worker_count__12': 531, 'ind1950__12': 0, 'census_place_id__13': 37995, 'worker_count__13': 5, 'ind1950__13': 307, 'census_place_id__14': 37995, 'worker_count__14': 1, 'ind1950__14': 636, 'census_place_id__15': 37582, 'worker_count__15': 3, 'ind1950__15': 379, 'census_place_id__16': 37582, 'worker_count__16': 2 ... 2900 parameters truncated ... 'worker_count__983': 1, 'ind1950__983': 326, 'census_place_id__984': 42154, 'worker_count__984': 5, 'ind1950__984': 379, 'census_place_id__985': 42154, 'worker_count__985': 3, 'ind1950__985': 868, 'census_place_id__986': 42486, 'worker_count__986': 826, 'ind1950__986': 0, 'census_place_id__987': 42486, 'worker_count__987': 1, 'ind1950__987': 358, 'census_place_id__988': 42486, 'worker_count__988': 4, 'ind1950__988': 636, 'census_place_id__989': 42486, 'worker_count__989': 2, 'ind1950__989': 307, 'census_place_id__990': 42486, 'worker_count__990': 2, 'ind1950__990': 836, 'census_place_id__991': 43397, 'worker_count__991': 377, 'ind1950__991': 105, 'census_place_id__992': 43397, 'worker_count__992': 34, 'ind1950__992': 488, 'census_place_id__993': 43397, 'worker_count__993': 1, 'ind1950__993': 906, 'census_place_id__994': 43397, 'worker_count__994': 10, 'ind1950__994': 416, 'census_place_id__995': 43397, 'worker_count__995': 1, 'ind1950__995': 899, 'census_place_id__996': 43397, 'worker_count__996': 9, 'ind1950__996': 499, 'census_place_id__997': 43430, 'worker_count__997': 7, 'ind1950__997': 409, 'census_place_id__998': 43430, 'worker_count__998': 4, 'ind1950__998': 868, 'census_place_id__999': 43430, 'worker_count__999': 1, 'ind1950__999': 859}
# 2024-05-15 12:37:14,312 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1850 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# ...
# 2024-05-15 12:37:22,082 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/10 (unordered)] {'census_place_id__0': 30066, 'worker_count__0': 8, 'ind1950__0': 337, 'census_place_id__1': 30066, 'worker_count__1': 6, 'ind1950__1': 716, 'census_place_id__2': 30066, 'worker_count__2': 4, 'ind1950__2': 429, 'census_place_id__3': 30431, 'worker_count__3': 380, 'ind1950__3': 0, 'census_place_id__4': 30431, 'worker_count__4': 25, 'ind1950__4': 997, 'census_place_id__5': 30431, 'worker_count__5': 1, 'ind1950__5': 836, 'census_place_id__6': 30643, 'worker_count__6': 2, 'ind1950__6': 896, 'census_place_id__7': 30570, 'worker_count__7': 7, 'ind1950__7': 826, 'census_place_id__8': 30570, 'worker_count__8': 1, 'ind1950__8': 699, 'census_place_id__9': 31016, 'worker_count__9': 387, 'ind1950__9': 0, 'census_place_id__10': 31016, 'worker_count__10': 21, 'ind1950__10': 997, 'census_place_id__11': 29702, 'worker_count__11': 2, 'ind1950__11': 868, 'census_place_id__12': 29204, 'worker_count__12': 2, 'ind1950__12': 817, 'census_place_id__13': 29204, 'worker_count__13': 12, 'ind1950__13': 246, 'census_place_id__14': 22276, 'worker_count__14': 6, 'ind1950__14': 896, 'census_place_id__15': 29204, 'worker_count__15': 1, 'ind1950__15': 888, 'census_place_id__16': 22276, 'worker_count__16': 1 ... 2900 parameters truncated ... 'worker_count__983': 1, 'ind1950__983': 489, 'census_place_id__984': 40037, 'worker_count__984': 1, 'ind1950__984': 679, 'census_place_id__985': 41331, 'worker_count__985': 2, 'ind1950__985': 849, 'census_place_id__986': 41331, 'worker_count__986': 5, 'ind1950__986': 489, 'census_place_id__987': 41331, 'worker_count__987': 9, 'ind1950__987': 847, 'census_place_id__988': 41331, 'worker_count__988': 3, 'ind1950__988': 308, 'census_place_id__989': 41331, 'worker_count__989': 1, 'ind1950__989': 846, 'census_place_id__990': 40874, 'worker_count__990': 818, 'ind1950__990': 0, 'census_place_id__991': 40874, 'worker_count__991': 18, 'ind1950__991': 997, 'census_place_id__992': 40874, 'worker_count__992': 6, 'ind1950__992': 636, 'census_place_id__993': 40874, 'worker_count__993': 1, 'ind1950__993': 836, 'census_place_id__994': 40874, 'worker_count__994': 1, 'ind1950__994': 936, 'census_place_id__995': 40874, 'worker_count__995': 1, 'ind1950__995': 687, 'census_place_id__996': 42019, 'worker_count__996': 1, 'ind1950__996': 656, 'census_place_id__997': 41965, 'worker_count__997': 2, 'ind1950__997': 888, 'census_place_id__998': 41965, 'worker_count__998': 2, 'ind1950__998': 817, 'census_place_id__999': 41965, 'worker_count__999': 2, 'ind1950__999': 246}
# 2024-05-15 12:37:22,092 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1860 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 12:37:22,092 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/10 (unordered)] {'census_place_id__0': 41856, 'worker_count__0': 719, 'ind1950__0': 0, 'census_place_id__1': 41856, 'worker_count__1': 20, 'ind1950__1': 997, 'census_place_id__2': 42073, 'worker_count__2': 36, 'ind1950__2': 105, 'census_place_id__3': 42073, 'worker_count__3': 1, 'ind1950__3': 488, 'census_place_id__4': 41331, 'worker_count__4': 1, 'ind1950__4': 916, 'census_place_id__5': 41210, 'worker_count__5': 2, 'ind1950__5': 868, 'census_place_id__6': 41210, 'worker_count__6': 2, 'ind1950__6': 409, 'census_place_id__7': 41210, 'worker_count__7': 1, 'ind1950__7': 379, 'census_place_id__8': 40544, 'worker_count__8': 1, 'ind1950__8': 488, 'census_place_id__9': 25914, 'worker_count__9': 2, 'ind1950__9': 546, 'census_place_id__10': 25914, 'worker_count__10': 1, 'ind1950__10': 489, 'census_place_id__11': 25914, 'worker_count__11': 2, 'ind1950__11': 308, 'census_place_id__12': 26144, 'worker_count__12': 874, 'ind1950__12': 0, 'census_place_id__13': 26144, 'worker_count__13': 3, 'ind1950__13': 836, 'census_place_id__14': 26144, 'worker_count__14': 1, 'ind1950__14': 636, 'census_place_id__15': 26144, 'worker_count__15': 21, 'ind1950__15': 997, 'census_place_id__16': 26144, 'worker_count__16': 2 ... 2900 parameters truncated ... 'worker_count__983': 1, 'ind1950__983': 656, 'census_place_id__984': 4668, 'worker_count__984': 6, 'ind1950__984': 879, 'census_place_id__985': 4530, 'worker_count__985': 433, 'ind1950__985': 0, 'census_place_id__986': 4940, 'worker_count__986': 2, 'ind1950__986': 619, 'census_place_id__987': 4940, 'worker_count__987': 9, 'ind1950__987': 868, 'census_place_id__988': 4940, 'worker_count__988': 2, 'ind1950__988': 506, 'census_place_id__989': 4668, 'worker_count__989': 2, 'ind1950__989': 656, 'census_place_id__990': 4940, 'worker_count__990': 1, 'ind1950__990': 726, 'census_place_id__991': 4530, 'worker_count__991': 6, 'ind1950__991': 997, 'census_place_id__992': 4953, 'worker_count__992': 3, 'ind1950__992': 888, 'census_place_id__993': 4953, 'worker_count__993': 2, 'ind1950__993': 526, 'census_place_id__994': 4940, 'worker_count__994': 1, 'ind1950__994': 409, 'census_place_id__995': 11346, 'worker_count__995': 6, 'ind1950__995': 868, 'census_place_id__996': 11346, 'worker_count__996': 1, 'ind1950__996': 506, 'census_place_id__997': 11494, 'worker_count__997': 15, 'ind1950__997': 105, 'census_place_id__998': 11494, 'worker_count__998': 1, 'ind1950__998': 499, 'census_place_id__999': 10628, 'worker_count__999': 31, 'ind1950__999': 0}
# 2024-05-15 12:37:22,102 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 12:37:22,107 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:22,107 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-05-15 12:37:22,108 INFO sqlalchemy.engine.Engine [cached since 7.943s ago] {'table_name': 'census_place_industry_count_1860', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-05-15 12:37:22,113 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1860 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 12:37:22,113 INFO sqlalchemy.engine.Engine [generated in 0.00186s (insertmanyvalues) 1/3 (unordered)] {'census_place_id__0': 51056, 'worker_count__0': 80, 'ind1950__0': 0, 'census_place_id__1': 50747, 'worker_count__1': 1, 'ind1950__1': 879, 'census_place_id__2': 46999, 'worker_count__2': 7, 'ind1950__2': 0, 'census_place_id__3': 41414, 'worker_count__3': 92, 'ind1950__3': 0, 'census_place_id__4': 41414, 'worker_count__4': 2, 'ind1950__4': 997, 'census_place_id__5': 49410, 'worker_count__5': 73, 'ind1950__5': 105, 'census_place_id__6': 49303, 'worker_count__6': 2, 'ind1950__6': 246, 'census_place_id__7': 49410, 'worker_count__7': 2, 'ind1950__7': 488, 'census_place_id__8': 49303, 'worker_count__8': 2, 'ind1950__8': 319, 'census_place_id__9': 49303, 'worker_count__9': 2, 'ind1950__9': 817, 'census_place_id__10': 49303, 'worker_count__10': 1, 'ind1950__10': 337, 'census_place_id__11': 49303, 'worker_count__11': 1, 'ind1950__11': 716, 'census_place_id__12': 49308, 'worker_count__12': 14, 'ind1950__12': 105, 'census_place_id__13': 49308, 'worker_count__13': 1, 'ind1950__13': 899, 'census_place_id__14': 49308, 'worker_count__14': 1, 'ind1950__14': 499, 'census_place_id__15': 44427, 'worker_count__15': 1, 'ind1950__15': 868, 'census_place_id__16': 44590, 'worker_count__16': 1 ... 2900 parameters truncated ... 'worker_count__983': 4, 'ind1950__983': 499, 'census_place_id__984': 35431, 'worker_count__984': 16, 'ind1950__984': 488, 'census_place_id__985': 35431, 'worker_count__985': 1, 'ind1950__985': 416, 'census_place_id__986': 35794, 'worker_count__986': 4, 'ind1950__986': 379, 'census_place_id__987': 35794, 'worker_count__987': 2, 'ind1950__987': 409, 'census_place_id__988': 35794, 'worker_count__988': 4, 'ind1950__988': 868, 'census_place_id__989': 35885, 'worker_count__989': 32, 'ind1950__989': 0, 'census_place_id__990': 35885, 'worker_count__990': 2, 'ind1950__990': 997, 'census_place_id__991': 35341, 'worker_count__991': 1, 'ind1950__991': 879, 'census_place_id__992': 35487, 'worker_count__992': 1, 'ind1950__992': 246, 'census_place_id__993': 35667, 'worker_count__993': 108, 'ind1950__993': 105, 'census_place_id__994': 35294, 'worker_count__994': 501, 'ind1950__994': 0, 'census_place_id__995': 35294, 'worker_count__995': 2, 'ind1950__995': 307, 'census_place_id__996': 35294, 'worker_count__996': 3, 'ind1950__996': 997, 'census_place_id__997': 35294, 'worker_count__997': 1, 'ind1950__997': 636, 'census_place_id__998': 35667, 'worker_count__998': 1, 'ind1950__998': 488, 'census_place_id__999': 34460, 'worker_count__999': 1066, 'ind1950__999': 105}
# 2024-05-15 12:37:22,123 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1860 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 68411 characters truncated ... __998)s, %(worker_count__998)s), (%(census_place_id__999)s, %(ind1950__999)s, %(worker_count__999)s)
# 2024-05-15 12:37:22,123 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/3 (unordered)] {'census_place_id__0': 34144, 'worker_count__0': 1338, 'ind1950__0': 0, 'census_place_id__1': 34144, 'worker_count__1': 58, 'ind1950__1': 997, 'census_place_id__2': 34144, 'worker_count__2': 6, 'ind1950__2': 636, 'census_place_id__3': 34144, 'worker_count__3': 2, 'ind1950__3': 307, 'census_place_id__4': 34144, 'worker_count__4': 1, 'ind1950__4': 836, 'census_place_id__5': 34144, 'worker_count__5': 1, 'ind1950__5': 358, 'census_place_id__6': 34421, 'worker_count__6': 4, 'ind1950__6': 656, 'census_place_id__7': 34528, 'worker_count__7': 9, 'ind1950__7': 698, 'census_place_id__8': 34528, 'worker_count__8': 4, 'ind1950__8': 346, 'census_place_id__9': 34528, 'worker_count__9': 2, 'ind1950__9': 896, 'census_place_id__10': 34528, 'worker_count__10': 1, 'ind1950__10': 399, 'census_place_id__11': 34902, 'worker_count__11': 3, 'ind1950__11': 888, 'census_place_id__12': 34902, 'worker_count__12': 11, 'ind1950__12': 246, 'census_place_id__13': 34902, 'worker_count__13': 3, 'ind1950__13': 817, 'census_place_id__14': 34460, 'worker_count__14': 11, 'ind1950__14': 416, 'census_place_id__15': 34460, 'worker_count__15': 28, 'ind1950__15': 499, 'census_place_id__16': 34460, 'worker_count__16': 88 ... 2900 parameters truncated ... 'worker_count__983': 7, 'ind1950__983': 506, 'census_place_id__984': 19964, 'worker_count__984': 2, 'ind1950__984': 946, 'census_place_id__985': 19964, 'worker_count__985': 10, 'ind1950__985': 896, 'census_place_id__986': 19964, 'worker_count__986': 7, 'ind1950__986': 698, 'census_place_id__987': 19964, 'worker_count__987': 1, 'ind1950__987': 399, 'census_place_id__988': 37683, 'worker_count__988': 1, 'ind1950__988': 489, 'census_place_id__989': 38383, 'worker_count__989': 1024, 'ind1950__989': 0, 'census_place_id__990': 38383, 'worker_count__990': 88, 'ind1950__990': 997, 'census_place_id__991': 38383, 'worker_count__991': 4, 'ind1950__991': 307, 'census_place_id__992': 38383, 'worker_count__992': 1, 'ind1950__992': 358, 'census_place_id__993': 38383, 'worker_count__993': 2, 'ind1950__993': 306, 'census_place_id__994': 30500, 'worker_count__994': 2, 'ind1950__994': 379, 'census_place_id__995': 30500, 'worker_count__995': 2, 'ind1950__995': 409, 'census_place_id__996': 30053, 'worker_count__996': 176, 'ind1950__996': 0, 'census_place_id__997': 38383, 'worker_count__997': 1, 'ind1950__997': 836, 'census_place_id__998': 38383, 'worker_count__998': 1, 'ind1950__998': 636, 'census_place_id__999': 30676, 'worker_count__999': 25, 'ind1950__999': 105}
# 2024-05-15 12:37:22,132 INFO sqlalchemy.engine.Engine INSERT INTO census_place_industry_count_1860 (census_place_id, ind1950, worker_count) VALUES (%(census_place_id__0)s, %(ind1950__0)s, %(worker_count__0)s), (%(census_place_id__1)s, %(ind1950__1)s, %(worker_count__1)s), (%(census_place_id__2)s, %(ind1 ... 14246 characters truncated ... __213)s, %(worker_count__213)s), (%(census_place_id__214)s, %(ind1950__214)s, %(worker_count__214)s)
# 2024-05-15 12:37:22,132 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/3 (unordered)] {'census_place_id__0': 30676, 'worker_count__0': 3, 'ind1950__0': 488, 'census_place_id__1': 31167, 'worker_count__1': 1, 'ind1950__1': 896, 'census_place_id__2': 30909, 'worker_count__2': 182, 'ind1950__2': 0, 'census_place_id__3': 30890, 'worker_count__3': 21, 'ind1950__3': 105, 'census_place_id__4': 30890, 'worker_count__4': 1, 'ind1950__4': 488, 'census_place_id__5': 31932, 'worker_count__5': 1, 'ind1950__5': 817, 'census_place_id__6': 30659, 'worker_count__6': 546, 'ind1950__6': 0, 'census_place_id__7': 30925, 'worker_count__7': 22, 'ind1950__7': 826, 'census_place_id__8': 30925, 'worker_count__8': 7, 'ind1950__8': 699, 'census_place_id__9': 30925, 'worker_count__9': 5, 'ind1950__9': 568, 'census_place_id__10': 30925, 'worker_count__10': 2, 'ind1950__10': 439, 'census_place_id__11': 31507, 'worker_count__11': 1, 'ind1950__11': 409, 'census_place_id__12': 31507, 'worker_count__12': 1, 'ind1950__12': 868, 'census_place_id__13': 23580, 'worker_count__13': 262, 'ind1950__13': 105, 'census_place_id__14': 23580, 'worker_count__14': 2, 'ind1950__14': 899, 'census_place_id__15': 23580, 'worker_count__15': 6, 'ind1950__15': 488, 'census_place_id__16': 23580, 'worker_count__16': 4 ... 545 parameters truncated ... 'worker_count__198': 1337, 'ind1950__198': 0, 'census_place_id__199': 53043, 'worker_count__199': 20, 'ind1950__199': 997, 'census_place_id__200': 53043, 'worker_count__200': 1, 'ind1950__200': 836, 'census_place_id__201': 53043, 'worker_count__201': 1, 'ind1950__201': 636, 'census_place_id__202': 53043, 'worker_count__202': 1, 'ind1950__202': 307, 'census_place_id__203': 53043, 'worker_count__203': 1, 'ind1950__203': 418, 'census_place_id__204': 52894, 'worker_count__204': 30, 'ind1950__204': 105, 'census_place_id__205': 53683, 'worker_count__205': 35, 'ind1950__205': 246, 'census_place_id__206': 53683, 'worker_count__206': 7, 'ind1950__206': 817, 'census_place_id__207': 52894, 'worker_count__207': 1, 'ind1950__207': 488, 'census_place_id__208': 53683, 'worker_count__208': 8, 'ind1950__208': 888, 'census_place_id__209': 53683, 'worker_count__209': 1, 'ind1950__209': 336, 'census_place_id__210': 53683, 'worker_count__210': 7, 'ind1950__210': 526, 'census_place_id__211': 53683, 'worker_count__211': 1, 'ind1950__211': 679, 'census_place_id__212': 53683, 'worker_count__212': 5, 'ind1950__212': 309, 'census_place_id__213': 53683, 'worker_count__213': 1, 'ind1950__213': 337, 'census_place_id__214': 53683, 'worker_count__214': 1, 'ind1950__214': 388}
# 2024-05-15 12:37:22,134 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 12:37:22,136 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# # 2. Create clusters
# Here we build clusters, the central unit of analysis of this project. Clusters are defined build as follows:
# - 2.0 Initialize the database by altering some system settings and uploading the template_usa_raster function
# - 2.1 Transform the census data into a population raster covering the entire USA
# - 2.2 Smooth the data with a convolutional kernel
# - 2.3 Cluster nearby high population tiles together using DBSCAN. Create a cluster-industry table, with the number of people in each cluster working in each industry

# %%
tcc.initialize_db()
# Out:
# 2024-05-15 12:37:31,375 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:31,375 INFO sqlalchemy.engine.Engine ALTER DATABASE clusterdb SET postgis.gdal_enabled_drivers = 'ENABLE_ALL';
# 2024-05-15 12:37:31,375 INFO sqlalchemy.engine.Engine [generated in 0.00026s] {}
# 2024-05-15 12:37:31,377 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 12:37:31,379 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:31,380 INFO sqlalchemy.engine.Engine DROP FUNCTION IF EXISTS get_template_usa_raster();
# CREATE OR REPLACE FUNCTION get_template_usa_raster()
# RETURNS raster AS
# $$
# DECLARE
#     usa_raster raster;
# BEGIN
#     WITH albers_bbox AS (
#         SELECT ST_Envelope(ST_Transform(ST_Union(geom), 5070)) AS bbox
#         FROM usa_geom
#         WHERE state_code != 'AK' and state_code != 'HI'
#     ),
#     bbox_params AS (
#         SELECT
#             ST_Y(ST_PointN(ST_ExteriorRing(bbox), 3)) AS upperlefty,
#             ST_X(ST_PointN(ST_ExteriorRing(bbox), 1)) AS upperleftx,
#             ST_XMAX(bbox) - ST_XMIN(bbox) AS width_meters,
#             ST_YMAX(bbox) - ST_YMIN(bbox) AS height_meters
#         FROM albers_bbox
#     )
#     SELECT ST_AddBand(ST_MakeEmptyRaster(
#             width => CAST(1 + width_meters / 1000 AS INTEGER), -- Total width in km
#             height => CAST(1 + height_meters / 1000 AS INTEGER), -- Total height in km
#             upperleftx => upperleftx,
#             upperlefty => upperlefty,
#             scalex => 1000,
#             scaley => -1000, -- Negative because y decreases as you move down
#             skewx => 0,
#             skewy => 0,
#             srid => 5070
#     ), 1, '64BF'::text, 0, 0)
#     INTO usa_raster FROM bbox_params;
#
#     RETURN usa_raster;
# END;
# $$
# LANGUAGE plpgsql;
# 2024-05-15 12:37:31,380 INFO sqlalchemy.engine.Engine [generated in 0.00019s] {}
# 2024-05-15 12:37:31,382 INFO sqlalchemy.engine.Engine COMMIT

# %%
tcc.rasterize_census_places()
# Out:
# 2024-05-15 12:37:32,321 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:32,323 INFO sqlalchemy.engine.Engine --- Create a raster with one band
# --- Each pixel has value equal to the sum of the population of the census places inside that pixel
# DROP TABLE IF EXISTS "rasterized_census_places_1850";
#
# CREATE TABLE "rasterized_census_places_1850" AS
# WITH usa_raster AS (
#         SELECT get_template_usa_raster() AS rast
#     ),
#     census_place_pop AS (
#         WITH census_place_pop_count AS (
#             SELECT census_place_id, SUM(worker_count) AS pop_count
#             FROM "census_place_industry_count_1850"
#             GROUP BY census_place_id
#         )
#         SELECT
#             cp_pop_count.pop_count AS pop_count,
#             cp.geom AS geom
#         FROM census_place_pop_count AS cp_pop_count
#         JOIN census_place AS cp
#         ON cp_pop_count.census_place_id = cp.id),
#    census_places_geomval AS (
#        SELECT ARRAY_AGG((ST_Transform(geom::geometry, 5070), pop_count::float)::geomval) AS geomvalset
#        FROM census_place_pop
#    )
# SELECT ST_SetValues(usa_raster.rast, 1, census_places_geomval.geomvalset, FALSE) AS rast
# FROM census_places_geomval
# CROSS JOIN usa_raster;
#
# SELECT AddRasterConstraints('rasterized_census_places_1850'::name, 'rast'::name);
# 2024-05-15 12:37:32,323 INFO sqlalchemy.engine.Engine [generated in 0.00023s] {}
# 2024-05-15 12:37:32,921 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 12:37:32,922 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:32,923 INFO sqlalchemy.engine.Engine --- Create a raster with one band
# --- Each pixel has value equal to the sum of the population of the census places inside that pixel
# DROP TABLE IF EXISTS "rasterized_census_places_1860";
#
# CREATE TABLE "rasterized_census_places_1860" AS
# WITH usa_raster AS (
#         SELECT get_template_usa_raster() AS rast
#     ),
#     census_place_pop AS (
#         WITH census_place_pop_count AS (
#             SELECT census_place_id, SUM(worker_count) AS pop_count
#             FROM "census_place_industry_count_1860"
#             GROUP BY census_place_id
#         )
#         SELECT
#             cp_pop_count.pop_count AS pop_count,
#             cp.geom AS geom
#         FROM census_place_pop_count AS cp_pop_count
#         JOIN census_place AS cp
#         ON cp_pop_count.census_place_id = cp.id),
#    census_places_geomval AS (
#        SELECT ARRAY_AGG((ST_Transform(geom::geometry, 5070), pop_count::float)::geomval) AS geomvalset
#        FROM census_place_pop
#    )
# SELECT ST_SetValues(usa_raster.rast, 1, census_places_geomval.geomvalset, FALSE) AS rast
# FROM census_places_geomval
# CROSS JOIN usa_raster;
#
# SELECT AddRasterConstraints('rasterized_census_places_1860'::name, 'rast'::name);
# 2024-05-15 12:37:32,923 INFO sqlalchemy.engine.Engine [generated in 0.00017s] {}
# 2024-05-15 12:37:33,522 INFO sqlalchemy.engine.Engine COMMIT

# %%
tcc.create_convolved_census_place_raster()
# Out:
# 2024-05-15 12:37:33,547 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:33,547 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS convolved_census_place_raster_1850
# 2024-05-15 12:37:33,547 INFO sqlalchemy.engine.Engine [generated in 0.00029s] {}
# 2024-05-15 12:37:33,549 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 12:37:33,550 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:33,551 INFO sqlalchemy.engine.Engine SELECT ST_AsGDALRaster(rast, 'GTIff') FROM rasterized_census_places_1850
# 2024-05-15 12:37:33,551 INFO sqlalchemy.engine.Engine [generated in 0.00025s] {}
# 2024-05-15 12:37:36,147 INFO sqlalchemy.engine.Engine CREATE TABLE convolved_census_place_raster_1850 (rast raster);
# 2024-05-15 12:37:36,147 INFO sqlalchemy.engine.Engine [generated in 0.00044s] {}
# 2024-05-15 12:37:36,150 INFO sqlalchemy.engine.Engine INSERT INTO convolved_census_place_raster_1850 (rast) VALUES (ST_FromGDALRaster(%(data)s))
# 2024-05-15 12:37:36,151 INFO sqlalchemy.engine.Engine [generated in 0.00027s] {'data': b'II*\x00\x08\x00\x00\x00\x10\x00\x00\x01\x03\x00\x01\x00\x00\x00\x04\x12\x00\x00\x01\x01\x03\x00\x01\x00\x00\x00\'\x0b\x00\x00\x02\x01\x03\x00\x01\x0 ... (412001931 characters truncated) ... 0\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'}
# 2024-05-15 12:37:38,326 INFO sqlalchemy.engine.Engine SELECT AddRasterConstraints('convolved_census_place_raster_1850'::name, 'rast'::name);
# 2024-05-15 12:37:38,327 INFO sqlalchemy.engine.Engine [generated in 0.00055s] {}
# 2024-05-15 12:37:38,433 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 12:37:38,440 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:38,440 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS convolved_census_place_raster_1860
# 2024-05-15 12:37:38,440 INFO sqlalchemy.engine.Engine [generated in 0.00019s] {}
# 2024-05-15 12:37:38,441 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 12:37:38,443 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:38,443 INFO sqlalchemy.engine.Engine SELECT ST_AsGDALRaster(rast, 'GTIff') FROM rasterized_census_places_1860
# 2024-05-15 12:37:38,443 INFO sqlalchemy.engine.Engine [generated in 0.00023s] {}
# 2024-05-15 12:37:40,957 INFO sqlalchemy.engine.Engine CREATE TABLE convolved_census_place_raster_1860 (rast raster);
# 2024-05-15 12:37:40,958 INFO sqlalchemy.engine.Engine [generated in 0.00042s] {}
# 2024-05-15 12:37:40,961 INFO sqlalchemy.engine.Engine INSERT INTO convolved_census_place_raster_1860 (rast) VALUES (ST_FromGDALRaster(%(data)s))
# 2024-05-15 12:37:40,961 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {'data': b'II*\x00\x08\x00\x00\x00\x10\x00\x00\x01\x03\x00\x01\x00\x00\x00\x04\x12\x00\x00\x01\x01\x03\x00\x01\x00\x00\x00\'\x0b\x00\x00\x02\x01\x03\x00\x01\x0 ... (405270799 characters truncated) ... 0\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'}
# 2024-05-15 12:37:43,135 INFO sqlalchemy.engine.Engine SELECT AddRasterConstraints('convolved_census_place_raster_1860'::name, 'rast'::name);
# 2024-05-15 12:37:43,135 INFO sqlalchemy.engine.Engine [generated in 0.00043s] {}
# 2024-05-15 12:37:43,267 INFO sqlalchemy.engine.Engine COMMIT

# %%
tcc.create_cluster()
# Out:
# 2024-05-15 12:37:43,304 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:43,306 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS "cluster_industry_1850";
# DROP TABLE IF EXISTS "cluster_1850";
#
# -- Create a temporary table to store the cluster geometries
# CREATE TEMPORARY TABLE cluster_geom_tmp ON COMMIT DROP AS
# WITH pixels AS (
#         SELECT (ST_PixelAsPolygons(rast, 1, TRUE)).*
#         FROM "convolved_census_place_raster_1850"
#     ),
#     filtered_pixel AS (
#         SELECT val, geom
#         FROM pixels
#         WHERE val > 100
#     ),
#     dbscan AS (
#         SELECT ST_ClusterDBSCAN(geom, eps := 100, minpoints := 1) OVER () AS cid, geom, val
#         FROM filtered_pixel
#     )
# SELECT cid AS cluster_id, ST_Union(geom) AS geom
# FROM dbscan
# GROUP BY cid;
#
# CREATE INDEX ON cluster_geom_tmp USING GIST (geom);
#
# -- Create a temporary table to store the cluster to census place crosswalk
# CREATE TEMPORARY TABLE cluster_census_place_crosswalk ON COMMIT DROP AS
# SELECT id AS census_place_id, cluster_id
# FROM cluster_geom_tmp JOIN "census_place"
# ON ST_Within(ST_Transform("census_place".geom::geometry, 5070), cluster_geom_tmp.geom);
#
# -- Create a temporary table to store the cluster population
# CREATE TEMPORARY TABLE cluster_pop_tmp ON COMMIT DROP AS
# WITH population_census_place AS (
#         SELECT census_place_id, SUM(worker_count) AS population
#         FROM "census_place_industry_count_1850"
#         GROUP BY census_place_id
#     )
# SELECT cc.cluster_id, SUM(pcc.population) AS population
# FROM population_census_place pcc JOIN cluster_census_place_crosswalk cc
# ON pcc.census_place_id = cc.census_place_id
# GROUP BY cluster_id;
#
# -- Create the cluster table
# CREATE TABLE "cluster_1850" AS
# SELECT cluster_geom_tmp.cluster_id, population, geom
# FROM cluster_geom_tmp JOIN cluster_pop_tmp
# ON cluster_geom_tmp.cluster_id = cluster_pop_tmp.cluster_id;
#
# CREATE INDEX ON "cluster_1850" USING GIST (geom);
# ALTER TABLE "cluster_1850" ADD PRIMARY KEY (cluster_id);
#
# -- Create the cluster industry table
# CREATE TABLE "cluster_industry_1850" AS
# SELECT cluster_id, ind1950, SUM(worker_count) AS worker_count
# FROM "census_place_industry_count_1850" AS industry
# JOIN cluster_census_place_crosswalk AS crosswalk
# ON industry.census_place_id = crosswalk.census_place_id
# GROUP BY cluster_id, ind1950
# ORDER BY cluster_id, ind1950;
#
# ALTER TABLE "cluster_industry_1850" ADD PRIMARY KEY (cluster_id, ind1950);
# ALTER TABLE "cluster_industry_1850" ADD FOREIGN KEY (cluster_id) REFERENCES "cluster_1850"(cluster_id);
# ALTER TABLE "cluster_industry_1850" ADD FOREIGN KEY (ind1950) REFERENCES "industry1950_code"(code);
#
# 2024-05-15 12:37:43,307 INFO sqlalchemy.engine.Engine [generated in 0.00038s] {}
# 2024-05-15 12:37:44,458 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 12:37:44,461 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:44,465 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS "cluster_industry_1860";
# DROP TABLE IF EXISTS "cluster_1860";
#
# -- Create a temporary table to store the cluster geometries
# CREATE TEMPORARY TABLE cluster_geom_tmp ON COMMIT DROP AS
# WITH pixels AS (
#         SELECT (ST_PixelAsPolygons(rast, 1, TRUE)).*
#         FROM "convolved_census_place_raster_1860"
#     ),
#     filtered_pixel AS (
#         SELECT val, geom
#         FROM pixels
#         WHERE val > 100
#     ),
#     dbscan AS (
#         SELECT ST_ClusterDBSCAN(geom, eps := 100, minpoints := 1) OVER () AS cid, geom, val
#         FROM filtered_pixel
#     )
# SELECT cid AS cluster_id, ST_Union(geom) AS geom
# FROM dbscan
# GROUP BY cid;
#
# CREATE INDEX ON cluster_geom_tmp USING GIST (geom);
#
# -- Create a temporary table to store the cluster to census place crosswalk
# CREATE TEMPORARY TABLE cluster_census_place_crosswalk ON COMMIT DROP AS
# SELECT id AS census_place_id, cluster_id
# FROM cluster_geom_tmp JOIN "census_place"
# ON ST_Within(ST_Transform("census_place".geom::geometry, 5070), cluster_geom_tmp.geom);
#
# -- Create a temporary table to store the cluster population
# CREATE TEMPORARY TABLE cluster_pop_tmp ON COMMIT DROP AS
# WITH population_census_place AS (
#         SELECT census_place_id, SUM(worker_count) AS population
#         FROM "census_place_industry_count_1860"
#         GROUP BY census_place_id
#     )
# SELECT cc.cluster_id, SUM(pcc.population) AS population
# FROM population_census_place pcc JOIN cluster_census_place_crosswalk cc
# ON pcc.census_place_id = cc.census_place_id
# GROUP BY cluster_id;
#
# -- Create the cluster table
# CREATE TABLE "cluster_1860" AS
# SELECT cluster_geom_tmp.cluster_id, population, geom
# FROM cluster_geom_tmp JOIN cluster_pop_tmp
# ON cluster_geom_tmp.cluster_id = cluster_pop_tmp.cluster_id;
#
# CREATE INDEX ON "cluster_1860" USING GIST (geom);
# ALTER TABLE "cluster_1860" ADD PRIMARY KEY (cluster_id);
#
# -- Create the cluster industry table
# CREATE TABLE "cluster_industry_1860" AS
# SELECT cluster_id, ind1950, SUM(worker_count) AS worker_count
# FROM "census_place_industry_count_1860" AS industry
# JOIN cluster_census_place_crosswalk AS crosswalk
# ON industry.census_place_id = crosswalk.census_place_id
# GROUP BY cluster_id, ind1950
# ORDER BY cluster_id, ind1950;
#
# ALTER TABLE "cluster_industry_1860" ADD PRIMARY KEY (cluster_id, ind1950);
# ALTER TABLE "cluster_industry_1860" ADD FOREIGN KEY (cluster_id) REFERENCES "cluster_1860"(cluster_id);
# ALTER TABLE "cluster_industry_1860" ADD FOREIGN KEY (ind1950) REFERENCES "industry1950_code"(code);
#
# 2024-05-15 12:37:44,465 INFO sqlalchemy.engine.Engine [generated in 0.00052s] {}
# 2024-05-15 12:37:46,211 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# # 3. Create time consistent clusters
# Here we build time consistent clusters, i.e., clusters having a consistent id across time. We do this by:
# - 3.1 Create a table with all clusters in all years and all cluster industry in all years. Create the "cluster intersection matching": a matching where two clusters (from different years) are matched if they intersect.
# - 3.3 Create a crosswalk table between cluster ids and time consistent cluster ids. Time consistent clusters are defined as connected components of bipartite graph representing the cluster intersection matching.
# - 3.4 Create a table with time consistent clusters and time consistent cluster industry data.

# %%
tcc.create_multiyear_tables_and_cluster_intersection_matching()
# Out:
# 2024-05-15 12:37:46,245 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:46,245 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS multiyear_cluster
# 2024-05-15 12:37:46,246 INFO sqlalchemy.engine.Engine [generated in 0.00038s] {}
# 2024-05-15 12:37:46,247 INFO sqlalchemy.engine.Engine CREATE TABLE multiyear_cluster AS (SELECT 1850 as year, cluster_id, population, geom FROM cluster_1850 UNION ALL SELECT 1860 as year, cluster_id, population, geom FROM cluster_1860 )
# 2024-05-15 12:37:46,248 INFO sqlalchemy.engine.Engine [generated in 0.00020s] {}
# 2024-05-15 12:37:46,250 INFO sqlalchemy.engine.Engine CREATE INDEX ON multiyear_cluster USING GIST (geom)
# 2024-05-15 12:37:46,250 INFO sqlalchemy.engine.Engine [generated in 0.00029s] {}
# 2024-05-15 12:37:46,252 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 12:37:46,253 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:46,256 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS "cluster_intersection_matching";
# CREATE TABLE "cluster_intersection_matching" AS
# SELECT c1.year as y1, c1.cluster_id AS id1, c2.year AS y2, c2.cluster_id AS id2
# FROM "multiyear_cluster" c1 JOIN "multiyear_cluster" c2
# ON ST_Intersects(c1.geom, c2.geom);
# 2024-05-15 12:37:46,256 INFO sqlalchemy.engine.Engine [generated in 0.00020s] {}
# 2024-05-15 12:37:46,299 INFO sqlalchemy.engine.Engine COMMIT
# 2024-05-15 12:37:46,300 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:46,300 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS multiyear_cluster_industry
# 2024-05-15 12:37:46,301 INFO sqlalchemy.engine.Engine [generated in 0.00022s] {}
# 2024-05-15 12:37:46,302 INFO sqlalchemy.engine.Engine CREATE TABLE multiyear_cluster_industry AS (SELECT 1850 as year, cluster_id, ind1950, worker_count FROM cluster_industry_1850 UNION ALL SELECT 1860 as year, cluster_id, ind1950, worker_count FROM cluster_industry_1860 )
# 2024-05-15 12:37:46,302 INFO sqlalchemy.engine.Engine [generated in 0.00019s] {}
# 2024-05-15 12:37:46,318 INFO sqlalchemy.engine.Engine COMMIT

# %%
tcc.create_crosswalk_cluster_uid_to_cluster_id()
# Out:
# 2024-05-15 12:37:46,343 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:46,344 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-05-15 12:37:46,344 INFO sqlalchemy.engine.Engine [cached since 32.18s ago] {'table_name': 'SELECT * FROM cluster_intersection_matching', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-05-15 12:37:46,345 INFO sqlalchemy.engine.Engine SELECT * FROM cluster_intersection_matching
# 2024-05-15 12:37:46,345 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-05-15 12:37:46,350 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-05-15 12:37:46,370 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:46,371 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-05-15 12:37:46,371 INFO sqlalchemy.engine.Engine [cached since 32.21s ago] {'table_name': 'crosswalk_cluster_uid_to_cluster_id', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-05-15 12:37:46,372 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-05-15 12:37:46,373 INFO sqlalchemy.engine.Engine [cached since 32.21s ago] {'table_name': 'crosswalk_cluster_uid_to_cluster_id', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-05-15 12:37:46,374 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-05-15 12:37:46,374 INFO sqlalchemy.engine.Engine [generated in 0.00047s] {'param_1': 'r', 'param_2': 'p', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2024-05-15 12:37:46,376 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-05-15 12:37:46,376 INFO sqlalchemy.engine.Engine [generated in 0.00021s] {'param_1': 'v', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2024-05-15 12:37:46,377 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-05-15 12:37:46,378 INFO sqlalchemy.engine.Engine [cached since 0.001862s ago] {'param_1': 'm', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2024-05-15 12:37:46,381 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_attribute.attname AS name, pg_catalog.format_type(pg_catalog.pg_attribute.atttypid, pg_catalog.pg_attribute.atttypmod) AS format_type, (SELECT pg_catalog.pg_get_expr(pg_catalog.pg_attrdef.adbin, pg_catalog.pg_attrdef.adrelid) AS pg_get_expr_1
# FROM pg_catalog.pg_attrdef
# WHERE pg_catalog.pg_attrdef.adrelid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_attrdef.adnum = pg_catalog.pg_attribute.attnum AND pg_catalog.pg_attribute.atthasdef) AS "default", pg_catalog.pg_attribute.attnotnull AS not_null, pg_catalog.pg_class.relname AS table_name, pg_catalog.pg_description.description AS comment, pg_catalog.pg_attribute.attgenerated AS generated, (SELECT json_build_object(%(json_build_object_2)s, pg_catalog.pg_attribute.attidentity = %(attidentity_1)s, %(json_build_object_3)s, pg_catalog.pg_sequence.seqstart, %(json_build_object_4)s, pg_catalog.pg_sequence.seqincrement, %(json_build_object_5)s, pg_catalog.pg_sequence.seqmin, %(json_build_object_6)s, pg_catalog.pg_sequence.seqmax, %(json_build_object_7)s, pg_catalog.pg_sequence.seqcache, %(json_build_object_8)s, pg_catalog.pg_sequence.seqcycle) AS json_build_object_1
# FROM pg_catalog.pg_sequence
# WHERE pg_catalog.pg_attribute.attidentity != %(attidentity_2)s AND pg_catalog.pg_sequence.seqrelid = CAST(CAST(pg_catalog.pg_get_serial_sequence(CAST(CAST(pg_catalog.pg_attribute.attrelid AS REGCLASS) AS TEXT), pg_catalog.pg_attribute.attname) AS REGCLASS) AS OID)) AS identity_options
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_attribute ON pg_catalog.pg_class.oid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_attribute.attnum > %(attnum_1)s AND NOT pg_catalog.pg_attribute.attisdropped LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_description.objsubid = pg_catalog.pg_attribute.attnum JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_attribute.attnum
# 2024-05-15 12:37:46,381 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {'json_build_object_2': 'always', 'attidentity_1': 'a', 'json_build_object_3': 'start', 'json_build_object_4': 'increment', 'json_build_object_5': 'minvalue', 'json_build_object_6': 'maxvalue', 'json_build_object_7': 'cache', 'json_build_object_8': 'cycle', 'attidentity_2': '', 'attnum_1': 0, 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'crosswalk_cluster_uid_to_cluster_id'}
# 2024-05-15 12:37:46,383 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname AS name, pg_catalog.format_type(pg_catalog.pg_type.typbasetype, pg_catalog.pg_type.typtypmod) AS attype, NOT pg_catalog.pg_type.typnotnull AS nullable, pg_catalog.pg_type.typdefault AS "default", pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AS visible, pg_catalog.pg_namespace.nspname AS schema, domain_constraints.condefs, domain_constraints.connames
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace LEFT OUTER JOIN (SELECT pg_catalog.pg_constraint.contypid AS contypid, array_agg(pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s)) AS condefs, array_agg(CAST(pg_catalog.pg_constraint.conname AS TEXT)) AS connames
# FROM pg_catalog.pg_constraint
# WHERE pg_catalog.pg_constraint.contypid != %(contypid_1)s GROUP BY pg_catalog.pg_constraint.contypid) AS domain_constraints ON pg_catalog.pg_type.oid = domain_constraints.contypid
# WHERE pg_catalog.pg_type.typtype = %(typtype_1)s ORDER BY pg_catalog.pg_namespace.nspname, pg_catalog.pg_type.typname
# 2024-05-15 12:37:46,383 INFO sqlalchemy.engine.Engine [generated in 0.00025s] {'pg_get_constraintdef_1': True, 'contypid_1': 0, 'typtype_1': 'd'}
# 2024-05-15 12:37:46,385 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname AS name, pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AS visible, pg_catalog.pg_namespace.nspname AS schema, lbl_agg.labels AS labels
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace LEFT OUTER JOIN (SELECT pg_catalog.pg_enum.enumtypid AS enumtypid, array_agg(CAST(pg_catalog.pg_enum.enumlabel AS TEXT) ORDER BY pg_catalog.pg_enum.enumsortorder) AS labels
# FROM pg_catalog.pg_enum GROUP BY pg_catalog.pg_enum.enumtypid) AS lbl_agg ON pg_catalog.pg_type.oid = lbl_agg.enumtypid
# WHERE pg_catalog.pg_type.typtype = %(typtype_1)s ORDER BY pg_catalog.pg_namespace.nspname, pg_catalog.pg_type.typname
# 2024-05-15 12:37:46,386 INFO sqlalchemy.engine.Engine [generated in 0.00022s] {'typtype_1': 'e'}
# 2024-05-15 12:37:46,387 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.oid, pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s)
# 2024-05-15 12:37:46,387 INFO sqlalchemy.engine.Engine [generated in 0.00022s] {'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'crosswalk_cluster_uid_to_cluster_id'}
# 2024-05-15 12:37:46,389 INFO sqlalchemy.engine.Engine SELECT attr.conrelid, array_agg(CAST(attr.attname AS TEXT) ORDER BY attr.ord) AS cols, attr.conname, min(attr.description) AS description, NULL AS extra
# FROM (SELECT con.conrelid AS conrelid, con.conname AS conname, con.conindid AS conindid, con.description AS description, con.ord AS ord, pg_catalog.pg_attribute.attname AS attname
# FROM pg_catalog.pg_attribute JOIN (SELECT pg_catalog.pg_constraint.conrelid AS conrelid, pg_catalog.pg_constraint.conname AS conname, pg_catalog.pg_constraint.conindid AS conindid, unnest(pg_catalog.pg_constraint.conkey) AS attnum, generate_subscripts(pg_catalog.pg_constraint.conkey, %(generate_subscripts_1)s) AS ord, pg_catalog.pg_description.description AS description
# FROM pg_catalog.pg_constraint LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid
# WHERE pg_catalog.pg_constraint.contype = %(contype)s AND pg_catalog.pg_constraint.conrelid IN (%(oids_1)s)) AS con ON pg_catalog.pg_attribute.attnum = con.attnum AND pg_catalog.pg_attribute.attrelid = con.conrelid
# WHERE con.conrelid IN (%(oids_1)s)) AS attr GROUP BY attr.conrelid, attr.conname ORDER BY attr.conrelid, attr.conname
# 2024-05-15 12:37:46,390 INFO sqlalchemy.engine.Engine [generated in 0.00039s] {'generate_subscripts_1': 1, 'contype': 'p', 'oids_1': 20297}
# 2024-05-15 12:37:46,392 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname, CASE WHEN (pg_catalog.pg_constraint.oid IS NOT NULL) THEN pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s) END AS anon_1, nsp_ref.nspname, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_class.oid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_constraint.contype = %(contype_1)s LEFT OUTER JOIN pg_catalog.pg_class AS cls_ref ON cls_ref.oid = pg_catalog.pg_constraint.confrelid LEFT OUTER JOIN pg_catalog.pg_namespace AS nsp_ref ON cls_ref.relnamespace = nsp_ref.oid LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname
# 2024-05-15 12:37:46,392 INFO sqlalchemy.engine.Engine [generated in 0.00023s] {'pg_get_constraintdef_1': True, 'contype_1': 'f', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'crosswalk_cluster_uid_to_cluster_id'}
# 2024-05-15 12:37:46,396 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_index.indrelid, cls_idx.relname AS relname_index, pg_catalog.pg_index.indisunique, pg_catalog.pg_constraint.conrelid IS NOT NULL AS has_constraint, pg_catalog.pg_index.indoption, cls_idx.reloptions, pg_catalog.pg_am.amname, CASE WHEN (pg_catalog.pg_index.indpred IS NOT NULL) THEN pg_catalog.pg_get_expr(pg_catalog.pg_index.indpred, pg_catalog.pg_index.indrelid) END AS filter_definition, pg_catalog.pg_index.indnkeyatts, pg_catalog.pg_index.indnullsnotdistinct, idx_cols.elements, idx_cols.elements_is_expr
# FROM pg_catalog.pg_index JOIN pg_catalog.pg_class AS cls_idx ON pg_catalog.pg_index.indexrelid = cls_idx.oid JOIN pg_catalog.pg_am ON cls_idx.relam = pg_catalog.pg_am.oid LEFT OUTER JOIN (SELECT idx_attr.indexrelid AS indexrelid, min(idx_attr.indrelid) AS min_1, array_agg(idx_attr.element ORDER BY idx_attr.ord) AS elements, array_agg(idx_attr.is_expr ORDER BY idx_attr.ord) AS elements_is_expr
# FROM (SELECT idx.indexrelid AS indexrelid, idx.indrelid AS indrelid, idx.ord AS ord, CASE WHEN (idx.attnum = %(attnum_1)s) THEN pg_catalog.pg_get_indexdef(idx.indexrelid, idx.ord + %(ord_1)s, %(pg_get_indexdef_1)s) ELSE CAST(pg_catalog.pg_attribute.attname AS TEXT) END AS element, idx.attnum = %(attnum_2)s AS is_expr
# FROM (SELECT pg_catalog.pg_index.indexrelid AS indexrelid, pg_catalog.pg_index.indrelid AS indrelid, unnest(pg_catalog.pg_index.indkey) AS attnum, generate_subscripts(pg_catalog.pg_index.indkey, %(generate_subscripts_1)s) AS ord
# FROM pg_catalog.pg_index
# WHERE NOT pg_catalog.pg_index.indisprimary AND pg_catalog.pg_index.indrelid IN (%(oids_1)s)) AS idx LEFT OUTER JOIN pg_catalog.pg_attribute ON pg_catalog.pg_attribute.attnum = idx.attnum AND pg_catalog.pg_attribute.attrelid = idx.indrelid
# WHERE idx.indrelid IN (%(oids_1)s)) AS idx_attr GROUP BY idx_attr.indexrelid) AS idx_cols ON pg_catalog.pg_index.indexrelid = idx_cols.indexrelid LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_index.indrelid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_index.indexrelid = pg_catalog.pg_constraint.conindid AND pg_catalog.pg_constraint.contype = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s])
# WHERE pg_catalog.pg_index.indrelid IN (%(oids_1)s) AND NOT pg_catalog.pg_index.indisprimary ORDER BY pg_catalog.pg_index.indrelid, cls_idx.relname
# 2024-05-15 12:37:46,396 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {'attnum_1': 0, 'ord_1': 1, 'pg_get_indexdef_1': True, 'attnum_2': 0, 'generate_subscripts_1': 1, 'param_1': 'p', 'param_2': 'u', 'param_3': 'x', 'oids_1': 20297}
# 2024-05-15 12:37:46,398 INFO sqlalchemy.engine.Engine SELECT attr.conrelid, array_agg(CAST(attr.attname AS TEXT) ORDER BY attr.ord) AS cols, attr.conname, min(attr.description) AS description, bool_and(pg_catalog.pg_index.indnullsnotdistinct) AS indnullsnotdistinct
# FROM (SELECT con.conrelid AS conrelid, con.conname AS conname, con.conindid AS conindid, con.description AS description, con.ord AS ord, pg_catalog.pg_attribute.attname AS attname
# FROM pg_catalog.pg_attribute JOIN (SELECT pg_catalog.pg_constraint.conrelid AS conrelid, pg_catalog.pg_constraint.conname AS conname, pg_catalog.pg_constraint.conindid AS conindid, unnest(pg_catalog.pg_constraint.conkey) AS attnum, generate_subscripts(pg_catalog.pg_constraint.conkey, %(generate_subscripts_1)s) AS ord, pg_catalog.pg_description.description AS description
# FROM pg_catalog.pg_constraint LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid
# WHERE pg_catalog.pg_constraint.contype = %(contype)s AND pg_catalog.pg_constraint.conrelid IN (%(oids_1)s)) AS con ON pg_catalog.pg_attribute.attnum = con.attnum AND pg_catalog.pg_attribute.attrelid = con.conrelid
# WHERE con.conrelid IN (%(oids_1)s)) AS attr JOIN pg_catalog.pg_index ON attr.conindid = pg_catalog.pg_index.indexrelid GROUP BY attr.conrelid, attr.conname ORDER BY attr.conrelid, attr.conname
# 2024-05-15 12:37:46,398 INFO sqlalchemy.engine.Engine [generated in 0.00026s] {'generate_subscripts_1': 1, 'contype': 'u', 'oids_1': 20297}
# 2024-05-15 12:37:46,400 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_class.oid = pg_catalog.pg_description.objoid AND pg_catalog.pg_description.objsubid = %(objsubid_1)s JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s)
# 2024-05-15 12:37:46,400 INFO sqlalchemy.engine.Engine [generated in 0.00027s] {'objsubid_1': 0, 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'crosswalk_cluster_uid_to_cluster_id'}
# 2024-05-15 12:37:46,401 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname, CASE WHEN (pg_catalog.pg_constraint.oid IS NOT NULL) THEN pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s) END AS anon_1, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_class.oid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_constraint.contype = %(contype_1)s LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname
# 2024-05-15 12:37:46,402 INFO sqlalchemy.engine.Engine [generated in 0.00023s] {'pg_get_constraintdef_1': True, 'contype_1': 'c', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog', 'filter_names_1': 'crosswalk_cluster_uid_to_cluster_id'}
# 2024-05-15 12:37:46,403 INFO sqlalchemy.engine.Engine
# DROP TABLE crosswalk_cluster_uid_to_cluster_id
# 2024-05-15 12:37:46,403 INFO sqlalchemy.engine.Engine [no key 0.00026s] {}
# 2024-05-15 12:37:46,404 INFO sqlalchemy.engine.Engine
# CREATE TABLE crosswalk_cluster_uid_to_cluster_id (
# 	cluster_uid BIGINT,
# 	year BIGINT,
# 	cluster_id BIGINT
# )
#
#
# 2024-05-15 12:37:46,404 INFO sqlalchemy.engine.Engine [no key 0.00019s] {}
# 2024-05-15 12:37:46,407 INFO sqlalchemy.engine.Engine INSERT INTO crosswalk_cluster_uid_to_cluster_id (cluster_uid, year, cluster_id) VALUES (%(cluster_uid__0)s, %(year__0)s, %(cluster_id__0)s), (%(cluster_uid__1)s, %(year__1)s, %(cluster_id__1)s), (%(cluster_uid__2)s, %(year__2)s, %(cluster_id__2)s), ( ... 58325 characters truncated ... 0)s, %(year__980)s, %(cluster_id__980)s), (%(cluster_uid__981)s, %(year__981)s, %(cluster_id__981)s)
# 2024-05-15 12:37:46,408 INFO sqlalchemy.engine.Engine [generated in 0.00080s (insertmanyvalues) 1/1 (unordered)] {'cluster_id__0': 138, 'cluster_uid__0': 0, 'year__0': 1860, 'cluster_id__1': 87, 'cluster_uid__1': 0, 'year__1': 1850, 'cluster_id__2': 184, 'cluster_uid__2': 1, 'year__2': 1850, 'cluster_id__3': 273, 'cluster_uid__3': 2, 'year__3': 1850, 'cluster_id__4': 51, 'cluster_uid__4': 3, 'year__4': 1850, 'cluster_id__5': 89, 'cluster_uid__5': 3, 'year__5': 1860, 'cluster_id__6': 272, 'cluster_uid__6': 4, 'year__6': 1850, 'cluster_id__7': 545, 'cluster_uid__7': 4, 'year__7': 1860, 'cluster_id__8': 406, 'cluster_uid__8': 5, 'year__8': 1860, 'cluster_id__9': 190, 'cluster_uid__9': 5, 'year__9': 1850, 'cluster_id__10': 314, 'cluster_uid__10': 6, 'year__10': 1850, 'cluster_id__11': 278, 'cluster_uid__11': 7, 'year__11': 1850, 'cluster_id__12': 176, 'cluster_uid__12': 8, 'year__12': 1850, 'cluster_id__13': 169, 'cluster_uid__13': 9, 'year__13': 1850, 'cluster_id__14': 299, 'cluster_uid__14': 10, 'year__14': 1850, 'cluster_id__15': 143, 'cluster_uid__15': 11, 'year__15': 1860, 'cluster_id__16': 92, 'cluster_uid__16': 11 ... 2846 parameters truncated ... 'cluster_uid__965': 783, 'year__965': 1860, 'cluster_id__966': 614, 'cluster_uid__966': 784, 'year__966': 1860, 'cluster_id__967': 191, 'cluster_uid__967': 785, 'year__967': 1860, 'cluster_id__968': 429, 'cluster_uid__968': 786, 'year__968': 1860, 'cluster_id__969': 122, 'cluster_uid__969': 787, 'year__969': 1860, 'cluster_id__970': 218, 'cluster_uid__970': 788, 'year__970': 1860, 'cluster_id__971': 570, 'cluster_uid__971': 789, 'year__971': 1860, 'cluster_id__972': 648, 'cluster_uid__972': 790, 'year__972': 1860, 'cluster_id__973': 49, 'cluster_uid__973': 791, 'year__973': 1860, 'cluster_id__974': 434, 'cluster_uid__974': 792, 'year__974': 1860, 'cluster_id__975': 211, 'cluster_uid__975': 793, 'year__975': 1860, 'cluster_id__976': 580, 'cluster_uid__976': 794, 'year__976': 1860, 'cluster_id__977': 530, 'cluster_uid__977': 795, 'year__977': 1860, 'cluster_id__978': 536, 'cluster_uid__978': 796, 'year__978': 1860, 'cluster_id__979': 520, 'cluster_uid__979': 797, 'year__979': 1860, 'cluster_id__980': 55, 'cluster_uid__980': 798, 'year__980': 1860, 'cluster_id__981': 148, 'cluster_uid__981': 799, 'year__981': 1860}
# 2024-05-15 12:37:46,413 INFO sqlalchemy.engine.Engine COMMIT

# %%
tcc.create_time_consistent_cluster()
# Out:
# 2024-05-15 12:37:46,436 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-15 12:37:46,437 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS "time_consistent_cluster_industry";
# DROP TABLE IF EXISTS "time_consistent_cluster";
#
# CREATE TABLE "time_consistent_cluster" AS
# WITH multiyear_cluster_with_uid AS (
#     SELECT m.cluster_uid, c.year, c.cluster_id, population, geom
#     FROM "crosswalk_cluster_uid_to_cluster_id" m JOIN "multiyear_cluster" c
#     ON m.cluster_id = c.cluster_id AND m.year = c.year
#     )
# SELECT cluster_uid, year, ST_Union(geom) AS geom, SUM(population) AS population
# FROM multiyear_cluster_with_uid
# GROUP BY cluster_uid, year
# ORDER BY cluster_uid, year;
#
# ALTER TABLE "time_consistent_cluster" ADD PRIMARY KEY (cluster_uid, year);
# CREATE INDEX ON "time_consistent_cluster" USING GIST (geom);
#
#
# CREATE TABLE "time_consistent_cluster_industry" AS
# WITH multiyear_cluster_industry_with_uid AS (
#     SELECT m.cluster_uid, ci.year, ci.cluster_id, ci.ind1950, worker_count
#     FROM "crosswalk_cluster_uid_to_cluster_id" m JOIN "multiyear_cluster_industry" ci
#     ON m.cluster_id = ci.cluster_id AND m.year = ci.year
# )
# SELECT cluster_uid, year, ind1950, SUM(worker_count) AS population
# FROM multiyear_cluster_industry_with_uid
# GROUP BY cluster_uid, year, ind1950
# ORDER BY cluster_uid, year, ind1950;
#
# ALTER TABLE "time_consistent_cluster_industry" ADD PRIMARY KEY (cluster_uid, year, ind1950);
# ALTER TABLE "time_consistent_cluster_industry" ADD FOREIGN KEY (cluster_uid, year) REFERENCES "time_consistent_cluster"(cluster_uid, year);
# ALTER TABLE "time_consistent_cluster_industry" ADD FOREIGN KEY (ind1950) REFERENCES "industry1950_code"(code);
# 2024-05-15 12:37:46,438 INFO sqlalchemy.engine.Engine [generated in 0.00029s] {}
# 2024-05-15 12:37:46,533 INFO sqlalchemy.engine.Engine COMMIT
